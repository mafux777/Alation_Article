# %% [markdown]
# <a href="https://colab.research.google.com/github/mafux777/Alation_Article/blob/master/notebooks/Work_with_Queries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Downloading Query Results programmatically

# %%
import requests
import pandas as pd

# %%
token = "p7uqevYeWBkWNA2X6WLWUEZJAysvnjTktNiDMqEQGX4"
host = "https://beta-sandbox.alationproserv.com"

def generic_get_text(api):
  return requests.get(host+api, headers=dict(token=token)).text

def generic_get_json(api):
  return requests.get(host+api, headers=dict(token=token)).json()

# %% [markdown]
# We will hard code the query ID here used for the example, all other params are obtained via APIs.
#
# Double check the text of the query (this will be the most recently published):

# %%
query_id = 44

query_text = generic_get_text(f"/integration/v1/query/{query_id}/sql/")
query_text
# Out:
# 'SELECT *  FROM public.rdbms_columns '

# %% [markdown]
# When was the query last executed? This gets us the valuable execution ID.

# %%
exec = generic_get_json(f"/integration/v1/query/{query_id}/result/latest/")
exec
# Out:
# {'id': 51,
#  'truncated': False,
#  'execution_event': {'executed_at': '2023-01-23T04:29:00.560603Z',
#   'canceled': False,
#   'execution_error': None,
#   'finished': True,
#   'finished_at': '2023-01-23T04:29:01.092257Z',
#   'seconds_taken': 0.531654}}

# %% [markdown]
# If we want even more details, we could use this API instead:

# %%
execs = requests.get(host + f"/integration/v1/query/{query_id}/execution_event/", headers=dict(token=token)).json()

# %% [markdown]
# Alation calls this an execution event, which coincides with either a user clicking on "run" or the query running on schedule.

# %%
pd.json_normalize(execs).sort_values('result.id', ascending=False).set_index('id')
# Out:
#      num_result_rows execution_error  canceled                  ts_executed  \
# id
# 148             1000            None     False  2023-01-23T04:29:00.560603Z
# 147             1000            None     False  2023-01-23T04:24:59.322473Z
#
#      elapsed_seconds  index_in_batch  batch_id  session_id  query_id  \
# id
# 148         0.531654               0       130          49        44
# 147         0.240971               0       129          48        44
#
#                     db_username  ... result.deleted             result.url  \
# id                               ...
# 148  matthias.funke@alation.com  ...          False  /execution_result/51/
# 147  matthias.funke@alation.com  ...          False  /execution_result/50/
#
#      result.storage_status                                 result.data_schema  \
# id
# 148             STORED_ALL  [{'original_name': 'dim_load_id', 'name': 'dim...
# 147             STORED_ALL  [{'original_name': 'dim_load_id', 'name': 'dim...
#
#     result.query.id          result.query.title    result.query.description  \
# id
# 148              44  All RDBMS Columns Exported  <p>For test purposes</p>\n
# 147              44  All RDBMS Columns Exported  <p>For test purposes</p>\n
#
#     datasource.id   datasource.title  datasource.url
# id
# 148             1  Alation Analytics        /data/1/
# 147             1  Alation Analytics        /data/1/
#
# [2 rows x 30 columns]

# %% [markdown]
# To download the result of the latest execution, we don't need the dataframe, we can refer to the result of the earlier API call (exec).

# %%
download = f"/integration/v1/result/{exec['id']}/csv/"

# %%
r = generic_get_text(download)

# %% [markdown]
# To create a dataframe, we wrap the string into a StringIO object, making it appear as a file to the Pandas API.

# %%
import io

df = pd.read_csv(io.StringIO(r))
df
# Out:
#        dim_load_id                 dim_ts_created  dim_checksum    id  \
# 0                1  2022-06-16 20:57:16.973927+00     310054800     1
# 1                1  2022-06-16 20:57:19.514006+00     512560782     2
# 2                1  2022-06-16 20:57:19.496668+00     981339989     3
# 3                1  2022-06-16 20:57:16.974033+00    3105227569     4
# 4                1  2022-06-16 20:57:19.496882+00    1322979056     5
# ...            ...                            ...           ...   ...
# 15732           97  2022-12-27 18:01:50.486377+00     464785358  7950
# 15733           97  2022-12-27 18:01:50.486581+00    1460079435  7951
# 15734           97  2022-12-27 18:01:50.486814+00    1886981156  7952
# 15735           97  2022-12-27 18:01:50.486697+00    2507154400  7953
# 15736           97  2022-12-27 18:01:50.486929+00    2128874978  7954
#
#        user_id                     ts_created                     ts_updated  \
# 0          NaN  2022-06-15 15:34:11.692637+00  2022-06-15 15:34:19.837969+00
# 1          NaN  2022-06-15 15:34:11.692637+00  2022-06-15 15:35:31.787642+00
# 2          NaN  2022-06-15 15:34:11.692637+00  2022-06-15 15:34:18.613225+00
# 3          NaN  2022-06-15 15:34:11.692637+00  2022-06-15 15:35:33.230795+00
# 4          NaN  2022-06-15 15:34:11.692637+00  2022-06-15 15:34:19.510486+00
# ...        ...                            ...                            ...
# 15732      NaN  2022-09-07 20:13:09.600692+00  2022-09-07 20:13:09.600692+00
# 15733      NaN  2022-09-07 20:13:09.600692+00  2022-09-07 20:13:09.600692+00
# 15734      NaN  2022-09-07 20:13:09.600692+00  2022-09-07 20:13:09.600692+00
# 15735      NaN  2022-09-07 20:13:09.600692+00  2022-09-07 20:13:09.600692+00
# 15736      NaN  2022-09-07 20:13:09.600692+00  2022-09-07 20:13:09.600692+00
#
#       ts_deleted  deleted  column_id  ...  expr_title  norm_type  \
# 0            NaN    False          1  ...         NaN     STRING
# 1            NaN    False          2  ...         NaN     STRING
# 2            NaN    False          3  ...         NaN     STRING
# 3            NaN    False          4  ...         NaN        NaN
# 4            NaN    False          5  ...         NaN        NaN
# ...          ...      ...        ...  ...         ...        ...
# 15732        NaN    False       7950  ...         NaN     STRING
# 15733        NaN    False       7951  ...         NaN     STRING
# 15734        NaN    False       7952  ...         NaN     STRING
# 15735        NaN    False       7953  ...         NaN     STRUCT
# 15736        NaN    False       7954  ...         NaN        INT
#
#        is_type_derived  position sensitive excluded is_transformed  \
# 0                False         1     False    False            NaN
# 1                False         2     False    False            NaN
# 2                False         3     False    False            NaN
# 3                False         4     False    False            NaN
# 4                False         5     False    False            NaN
# ...                ...       ...       ...      ...            ...
# 15732            False         2     False    False            NaN
# 15733            False         1     False    False            NaN
# 15734            False         1     False    False            NaN
# 15735            False         5     False    False            NaN
# 15736            False         2     False    False            NaN
#
#           attribute_url  sensitivity classification
# 0         /attribute/1/          NaN            NaN
# 1         /attribute/2/          NaN            NaN
# 2         /attribute/3/          NaN            NaN
# 3         /attribute/4/          NaN            NaN
# 4         /attribute/5/          NaN            NaN
# ...                 ...          ...            ...
# 15732  /attribute/7950/          NaN            NaN
# 15733  /attribute/7951/          NaN            NaN
# 15734  /attribute/7952/          NaN            NaN
# 15735  /attribute/7953/          NaN            NaN
# 15736  /attribute/7954/          NaN            NaN
#
# [15737 rows x 35 columns]

# %% [markdown]
# Note how the resulting dataframe can contain much more than the 1000 rows initially indicated by the API.
