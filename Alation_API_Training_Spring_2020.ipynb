# %% [markdown]
# <a href="https://colab.research.google.com/github/mafux777/Alation_Article/blob/master/Alation_API_Training_Spring_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Alation API Training Worksheet

# %% [markdown]
# We need to import just a small number of libraries to create an Alation Instance. You can use this Class to test against any official or unofficial API.

# %%
import pandas as pd
import os
import requests

import time
import json

import pprint
pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# The class AlationInstance is created with a URL, username and password.

# %%
import urllib

# The AlationInstance class is a handle to an Alation server defined by a URL
# A server admin user name and password needs to be provided and all API actions
# will be run as that user
class AlationInstance():
    # The __init__ method is the constructor used for instantiating
    # email: the up to 30 chars user name, often the email, but for long emails could be cut off
    # password: could be the LDAP password, as well
    # verify: Requests verifies SSL certificates for HTTPS requests, just like a web browser.
    # By default, SSL verification is enabled, and Requests will throw a SSLError if it’s unable to verify the certificate
    def __init__(self, host, account, password, verify=True):
        self.host = host
        self.verify = verify
        self.account = account
        self.password = password
        self.token = self.get_token()
        self.headers = self.login(account, password)

    # The login method is used to obtain a session ID and relevant cookies
    # They are cached in the headers variable
    # account: the up to 30 chars user name, often the email, but for long emails could be cut off
    # password: could be the LDAP password, as well
    def login(self, account, password):
        URL = self.host + '/login/'

        s = requests.Session()
        s.get(URL, verify=self.verify)

        # get the cookie token
        csrftoken = s.cookies.get('csrftoken')

        # login with user name and password (and token)
        payload = {"csrfmiddlewaretoken": csrftoken, "ldap_user": account, "password": password}
        headers = {"Referer": URL}
        log_me("Logging in to {}".format(URL))
        r = s.post(URL, data=payload, verify=self.verify, headers=headers)

        # get the session ID and store it for all future API calls
        sessionid = s.cookies.get('sessionid')
        if not sessionid:
            log_me('No session ID, probably wrong user name / password')
        headers = {"X-CSRFToken": csrftoken,
                   "Cookie": f"csrftoken={csrftoken}; sessionid={sessionid}",
                   "Referer": URL
                   }

        return headers

    def get_token(self):
        change_token = "/api/v1/changeToken/"  # if you already have a token, use this url
        new_token = "/api/v1/getToken/"  # if you have never generated a token, use this url
        data = dict(username=self.account, password=self.password)
        response = requests.post(self.host + new_token, data=data)
        api_token = response.text
        if api_token == "EXISTING":
            response = requests.post(self.host + change_token, data=data)
            api_token = response.text
        return api_token

    # The generic_api_post method posts a request to Alation and if necessary checks the status
    def generic_api_post(self, api, params=None, body=None, official=False):
        if official:
            headers_final = dict(token=self.token)
        else:
            headers_final = self.headers
            headers_final['Referer'] = self.host + api
        r = requests.post(self.host + api, json=body, params=params, headers=headers_final)

        if r.status_code:
            r_parsed = r.json()
            # do we need to ask the job status API for help?
            if 'job_id' in r_parsed:
                params = dict(id=r_parsed['job_id'])
                url_job = "/api/v1/bulk_metadata/job/"
                # Let's wait for the job to finish
                while (True):
                    status = self.generic_api_get(api=url_job, params=params, official=True, verify=self.verify)
                    if status['status'] != 'running':
                        objects = status['result']
                        # if objects:
                        #     # for error in error_objects:
                        #     print(objects)
                        # else:
                        #     #print(status)
                        #     pass
                        break
                r_parsed = status
            return r_parsed
        else:
            return r.content

    # The generic_api_post method posts a request to Alation and if necessary checks the status
    def generic_api_put(self, api, params=None, body=None):
        r = requests.put(self.host + api, json=body, params=params, headers=self.headers, verify=self.verify)
        return r.content

    # The generic_api_post method posts a request to Alation and if necessary checks the status
    def generic_api_patch(self, api, params=None, body=None):
        r = requests.patch(self.host + api, json=body, params=params, headers=self.headers, verify=self.verify)
        return r.content

    # The generic_api_get implements a REST get, with API token if official or Cookie if not.
    # If the callers sends header, it needs to contain API or cookie
    def generic_api_get(self, api, headers=None, params=None, official=False):
        if headers:
            # caller has supplied the headers
            headers_final = headers
        else:
            if official:
                headers_final = dict(token=self.token)
            else:
                headers_final = self.headers
                headers_final['Referer'] = self.host + api
        r = requests.get(self.host + api, headers=headers_final, params=params, verify=self.verify)
        if r.status_code in [200, 201]:
            try:
                return r.json()
            except:
                return r.content # for LogicalMetadata API which does not use standard JSON
        else:
            return r.content

# %% [markdown]
# Let's create our first AlationInstance object:

# %%
def log_me(text):
  print(text)

alation = AlationInstance('http://18.218.6.215',
                         'matthias+2@alation.com',
                         '7aksHHJki.GGy!NF8VGa')
# Out:
# Logging in to http://18.218.6.215/login/

# %% [markdown]
# **Queries** in Alation are documents of SQL text. They can have multiple SQL statements, and their content is editable by their creator. They are associated with a single data source on creation and cannot be moved to a different data source.
#
# **Queries** can be in draft state (unsaved), saved, or published. If a **query** is published it is also saved.
#
# When a **query** is executed, each statement (CREATE, UPDATE, INSERT, SELECT, etc) is executed in turn by the database, and Alation stores metadata in an **execution event**. If the statement returns a **result**, Alation caches up to 16MB of that result on the server (unless the user is running an export, in which case only a 1000 row result preview is cached). These cached results (sometimes whole, sometimes partial) are available via API or in the Alation catalog until they expire. The expiration period is configurable on your server, but defaults to 1 week. Small **results** (by default less than 1MB) are stored indefinitely, with no expiration date.
#
# In addition to an **execution event**, there is also a **session** and a **batch** associated with the execution of a query. If a query contains multiple **statements**, then multiple **events** -- one event per query statement -- would be created and would belong to a single **execution batch**. Each execution of a query in Compose will create a new batch; a single **session** could have many such batches. In the case of scheduled queries, a new session is created for each run and each such session will have only a single batch; each scheduled query is run via a designated Celery task.
#
# # Summary
#
#
#
# ---
# term | dependency | description
# ---- | ---------- | -----------
# Query | N/A | a tab in compose, one more statements
# Statement | ^Query | separated by ";"
# Session | N/A | a period of time
# (Execution) Batch | ^Session | Click on "run"
# (Execution) Event | ^Batch | One per statement
# (Execution) Result | ^Event | The results of one statement

# %%
my_query = dict(
    datasource_id=42,
    content="select count(*) from banana;",
    saved=True#,
    #author=dict(id=9, email='matthias+2@alation.com', username='matthias+2@alation.com')
)
q = alation.generic_api_post('/integration/v1/query/', body=my_query, official=True)
pp.pprint(q)
# Out:
# {   'autosave_content': 'select count(*) from banana;',
#     'catalog_url': '/query/95/',
#     'compose_url': '/compose/query/95/',
#     'content': 'select count(*) from banana;',
#     'datasource': {   'id': 42,
#                       'title': 'Fennel',
#                       'uri': 'postgresql://fennel2.cluster-cingqyuv6npc.us-east-2.rds.amazonaws.com:5433/fennel',
#                       'url': '/data/42/'},
#     'datasource_id': 42,
#     'description': '',
#     'has_unsaved_changes': False,
#     'id': 95,
#     'published': False,
#     'saved': True,
#     'schedules': [],
#     'title': '',
#     'ts_last_saved': '2020-04-21T07:57:02.431972-07:00',
#     'url': '/integration/v1/query/95/'}

# %% [markdown]
# The previous query, alas, has no title and no description. At least is has a number.
#
# Since there is no official API to execute the query, we will schedule a different [query](http://18.218.6.215/compose/query/85/) to run automatically and see what we get.

# %%
q = alation.generic_api_get('/integration/v1/query/85/', official=True)
pp.pprint(q)
# Out:
# {   'autosave_content': 'select schema_name, table_name, attribute_name, '
#                         'count(1) as freq\n'
#                         'from public.zucchini\n'
#                         'group by 1, 2, 3\n'
#                         'order by 4 DESC\n'
#                         'limit 1000;\n'
#                         '\n'
#                         'select now();',
#     'catalog_url': '/query/85/',
#     'compose_url': '/compose/query/85/',
#     'content': 'select schema_name, table_name, attribute_name, count(1) as '
#                'freq\n'
#                'from public.zucchini\n'
#                'group by 1, 2, 3\n'
#                'order by 4 DESC\n'
#                'limit 1000;\n'
#                '\n'
#                'select now();',
#     'datasource': {   'id': 42,
#                       'title': 'Fennel',
#                       'uri': 'postgresql://fennel2.cluster-cingqyuv6npc.us-east-2.rds.amazonaws.com:5433/fennel',
#                       'url': '/data/42/'},
#     'datasource_id': 42,
#     'description': '<p>i have decided to publish this to enlighten the '
#                    'world</p>\n',
#     'has_unsaved_changes': False,
#     'id': 85,
#     'published': True,
#     'saved': True,
#     'schedules': [   {   'celery_queue': 'run_scheduling',
#                          'celery_task_name': 'rosemeta.tasks.query_scheduling.run_query_1',
#                          'cron_expression': '7 * * * *',
#                          'db_connection': {   'ts_last_used': '2020-04-21T07:41:15.171794-07:00',
#                                               'ts_modified': '2020-04-19T04:35:10.519541-07:00',
#                                               'uri': 'postgresql://fennel2.cluster-cingqyuv6npc.us-east-2.rds.amazonaws.com:5433/fennel',
#                                               'username': 'matthias.funke'},
#                          'enabled': True,
#                          'latest_session': {   'batch_ids': [237],
#                                                'client_session_id': '2020-04-21T07:07:00.202590#acdad7e6',
#                                                'id': 104,
#                                                'query_id': 85,
#                                                'sandbox_id': 'schedule-1',
#                                                'ts_start': '2020-04-21T07:07:00.205050-07:00'},
#                          'overdue': False,
#                          'ts_last_attempt': '2020-04-21T07:07:00.026342-07:00',
#                          'ts_next_run': '2020-04-21T15:07:00Z',
#                          'user': {   'is_active': True,
#                                      'username': 'matthias+1@alation.com'}}],
#     'title': 'base fennel query',
#     'ts_last_saved': '2020-04-19T06:03:15.107905-07:00',
#     'url': '/integration/v1/query/85/'}

# %% [markdown]
# This output gives us interesting details about the automatically executed results. Perhaps we can use any?

# %%
params=dict(query_id=q['id'])
exec_session = alation.generic_api_get('/integration/v1/query/execution_session/', params=params, official=True)
pp.pprint(exec_session)
# Out:
# [   {   'batch_ids': [195, 196, 199, 203, 204, 205, 206],
#         'client_session_id': '2020-04-19T11:35:08.036Z#15d15b7373134',
#         'id': 80,
#         'is_scheduled': False,
#         'query_id': 85,
#         'sandbox_id': 'compose-85',
#         'ts_start': '2020-04-19T04:36:14.269717-07:00'},
#     {   'batch_ids': [200, 201],
#         'client_session_id': '2020-04-19T05:20:00.261962#218a53c4',
#         'id': 83,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-19T05:20:00.264583-07:00'},
#     {   'batch_ids': [202, 207],
#         'client_session_id': '2020-04-19T05:41:00.208143#936dda61',
#         'id': 84,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-19T05:41:00.211132-07:00'},
#     {   'batch_ids': [208],
#         'client_session_id': '2020-04-19T06:04:00.233709#80b85921',
#         'id': 85,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-19T06:04:00.236137-07:00'},
#     {   'batch_ids': [209],
#         'client_session_id': '2020-04-19T06:07:00.187095#763b7c83',
#         'id': 86,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-19T06:07:00.189539-07:00'},
#     {   'batch_ids': [214],
#         'client_session_id': '2020-04-19T13:40:22.817Z#a6b8c82492533',
#         'id': 90,
#         'is_scheduled': False,
#         'query_id': 85,
#         'sandbox_id': 'query-form-85',
#         'ts_start': '2020-04-19T06:40:24.552349-07:00'},
#     {   'batch_ids': [215],
#         'client_session_id': '2020-04-19T07:07:00.186185#5e7d616a',
#         'id': 91,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-19T07:07:00.188776-07:00'},
#     {   'batch_ids': [226],
#         'client_session_id': '2020-04-19T08:07:00.197407#be370a4c',
#         'id': 93,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-19T08:07:00.200072-07:00'},
#     {   'batch_ids': [227],
#         'client_session_id': '2020-04-19T09:07:00.414836#a727650b',
#         'id': 94,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-19T09:07:00.419327-07:00'},
#     {   'batch_ids': [229],
#         'client_session_id': '2020-04-19T10:07:00.181247#a63ac4bd',
#         'id': 96,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-19T10:07:00.183669-07:00'},
#     {   'batch_ids': [230],
#         'client_session_id': '2020-04-19T11:07:00.204948#ec41ae85',
#         'id': 97,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-19T11:07:00.207418-07:00'},
#     {   'batch_ids': [231],
#         'client_session_id': '2020-04-21T02:00:20.907590#601c1783',
#         'id': 98,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-21T02:00:20.912920-07:00'},
#     {   'batch_ids': [232],
#         'client_session_id': '2020-04-21T02:07:00.247713#097f5682',
#         'id': 99,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-21T02:07:00.250547-07:00'},
#     {   'batch_ids': [233],
#         'client_session_id': '2020-04-21T03:07:00.192510#50f85a2e',
#         'id': 100,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-21T03:07:00.194995-07:00'},
#     {   'batch_ids': [234],
#         'client_session_id': '2020-04-21T04:07:00.217786#d309f674',
#         'id': 101,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-21T04:07:00.220249-07:00'},
#     {   'batch_ids': [235],
#         'client_session_id': '2020-04-21T05:07:00.187552#121879ac',
#         'id': 102,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-21T05:07:00.189727-07:00'},
#     {   'batch_ids': [236],
#         'client_session_id': '2020-04-21T06:07:00.402103#3a1aacd0',
#         'id': 103,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-21T06:07:00.404752-07:00'},
#     {   'batch_ids': [237],
#         'client_session_id': '2020-04-21T07:07:00.202590#acdad7e6',
#         'id': 104,
#         'is_scheduled': True,
#         'query_id': 85,
#         'sandbox_id': 'schedule-1',
#         'ts_start': '2020-04-21T07:07:00.205050-07:00'}]

# %% [markdown]
# The result shows a small bug in the Alation code: for a scheduled execution run, the timestamp does not show the UTC time.
#
# Let's get the batch details by using the execution batch API

# %%
batch_id = exec_session[-1]['batch_ids'][0]
batch = alation.generic_api_get(f'/integration/v1/query/execution_batch/{batch_id}/', official=True)
pp.pprint(batch)
# Out:
# {   'events': [   {'id': 431, 'index_in_batch': 1},
#                   {'id': 430, 'index_in_batch': 0}],
#     'id': 237,
#     'query_id': 85,
#     'session_id': 104}

# %% [markdown]
# Let's get the execution event details.

# %%
base_url = "http://18.218.6.215"

for event in batch['events']:
  event_id = event['id']
  exec_event = alation.generic_api_get(f"/integration/v1/query/execution_event/{event_id}/", official=True)
  print('-----------------------------')
  pp.pprint(exec_event)
  print('-----------------------------')
  print(f"{base_url}{exec_event['result']['url']} ({exec_event['result']['title']})")
# Out:
# -----------------------------
# {   'batch_id': 237,
#     'canceled': False,
#     'datasource': {'id': 42, 'title': 'Fennel', 'url': '/data/42/'},
#     'db_username': None,
#     'elapsed_seconds': 0.041014,
#     'execution_error': None,
#     'id': 431,
#     'index_in_batch': 1,
#     'num_result_rows': 1,
#     'query_id': 85,
#     'result': {   'byte_count': 35,
#                   'data_schema': [   {   'name': 'now',
#                                          'norm_type': 'TIMESTAMP',
#                                          'original_name': 'now',
#                                          'type': 'timestamptz'}],
#                   'deleted': False,
#                   'expired': False,
#                   'id': 146,
#                   'query': {   'description': '<p>i have decided to publish '
#                                               'this to enlighten the '
#                                               'world</p>\n',
#                                'id': 85,
#                                'title': 'base fennel query'},
#                   'row_count': 1,
#                   'storage_status': 'STORED_ALL',
#                   'title': 'Scheduled result on base fennel query 2020-04-21',
#                   'truncated': False,
#                   'ts_created': '2020-04-21T07:07:00.492731-07:00',
#                   'ts_expiration': None,
#                   'url': '/execution_result/146/'},
#     'session_id': 104,
#     'statement_content': 'select now();',
#     'ts_executed': '2020-04-21T07:07:00.430057-07:00',
#     'url': '/compose_execution_session/104/?from_event=431'}
# -----------------------------
# http://18.218.6.215/execution_result/146/ (Scheduled result on base fennel query 2020-04-21)
# -----------------------------
# {   'batch_id': 237,
#     'canceled': False,
#     'datasource': {'id': 42, 'title': 'Fennel', 'url': '/data/42/'},
#     'db_username': 'matthias.funke',
#     'elapsed_seconds': 0.175182,
#     'execution_error': None,
#     'id': 430,
#     'index_in_batch': 0,
#     'num_result_rows': 1000,
#     'query_id': 85,
#     'result': {   'byte_count': 52953,
#                   'data_schema': [   {   'name': 'schema_name',
#                                          'norm_type': 'STRING',
#                                          'original_name': 'schema_name',
#                                          'type': 'text'},
#                                      {   'name': 'table_name',
#                                          'norm_type': 'STRING',
#                                          'original_name': 'table_name',
#                                          'type': 'text'},
#                                      {   'name': 'attribute_name',
#                                          'norm_type': 'STRING',
#                                          'original_name': 'attribute_name',
#                                          'type': 'text'},
#                                      {   'name': 'freq',
#                                          'norm_type': 'INT',
#                                          'original_name': 'freq',
#                                          'type': 'int8'}],
#                   'deleted': False,
#                   'expired': False,
#                   'id': 145,
#                   'query': {   'description': '<p>i have decided to publish '
#                                               'this to enlighten the '
#                                               'world</p>\n',
#                                'id': 85,
#                                'title': 'base fennel query'},
#                   'row_count': 1000,
#                   'storage_status': 'STORED_ALL',
#                   'title': 'Scheduled result on base fennel query 2020-04-21',
#                   'truncated': False,
#                   'ts_created': '2020-04-21T07:07:00.406115-07:00',
#                   'ts_expiration': None,
#                   'url': '/execution_result/145/'},
#     'session_id': 104,
#     'statement_content': 'select schema_name, table_name, attribute_name, '
#                          'count(1) as freq\n'
#                          'from public.zucchini\n'
#                          'group by 1, 2, 3\n'
#                          'order by 4 DESC\n'
#                          'limit 1000;',
#     'ts_executed': '2020-04-21T07:07:00.205050-07:00',
#     'url': '/compose_execution_session/104/?from_event=430'}
# -----------------------------
# http://18.218.6.215/execution_result/145/ (Scheduled result on base fennel query 2020-04-21)

# %% [markdown]
# Now let's use an unoffical API to get hold of the actual result.

# %%
result_id = 148#exec_event['result']['id']
data_schema = exec_event['result']['data_schema']
cols = [schema['name'] for schema in data_schema]
res = alation.generic_api_get(f'/ajax/execution_result_data/{result_id}/')
pd.DataFrame(res, columns=cols)
# Out:
#     schema_name              table_name   attribute_name freq
# 0        public               inventory            store   18
# 1        public               employees          emp_yrs   18
# 2        public               inventory      store_state   18
# 3        public                   parts              cat   18
# 4        public               employees         emp_name   18
# ..          ...                     ...              ...  ...
# 995   loan_data  full_loan_details_full  settlement_term    5
# 996   loan_data  full_loan_details_full     num_tl_30dpd    5
# 997        bank       uic_credit_data_2        bill_amt4    5
# 998        bank       uic_credit_data_2        education    5
# 999        bank       uic_credit_data_2        bill_amt2    5
#
# [1000 rows x 4 columns]

# %%
res
# Out:
# [['public', 'inventory', 'store', '18'],
#  ['public', 'employees', 'emp_yrs', '18'],
#  ['public', 'inventory', 'store_state', '18'],
#  ['public', 'parts', 'cat', '18'],
#  ['public', 'employees', 'emp_name', '18'],
#  ['public', 'customers', 'cust_age', '18'],
#  ['public', 'parts', 'sku', '18'],
#  ['public', 'employees', 'emp_iss', '18'],
#  ['public', 'customers', 'cust_name', '18'],
#  ['public', 'customers', 'cust_zip', '18'],
#  ['public', 'inventory', 'stocked', '18'],
#  ['public', 'employees', 'emp_perf', '18'],
#  ['public', 'inventory', 'low_alert', '18'],
#  ['public', 'inventory', 'store_zip', '18'],
#  ['public', 'employees', 'emp_st', '18'],
#  ['public', 'customers', 'cust_state', '18'],
#  ['public', 'parts', 'count', '18'],
#  ['public', 'customers', 'cust_app', '18'],
#  ['public', 'inventory', 'overstocked', '18'],
#  ['public', 'employees', 'emp_bonus', '18'],
#  ['public', 'employees', 'emp_salary', '18'],
#  ['public', 'employees', 'emp_age', '18'],
#  ['public', 'parts', 'sub_cat', '18'],
#  ['public', 'employees', 'emp_role', '18'],
#  ['public', 'employees', 'emp_zipcode', '18'],
#  ['public', 'customers', 'cust_cty', '18'],
#  ['public', 'employees', 'emp_cty', '18'],
#  ['public', 'employees', 'emp_sales', '18'],
#  ['public', 'employees', 'emp_lastname', '18'],
#  ['public', 'customers', 'cust_lastname', '18'],
#  ['public', 'sales', 'hold', '17'],
#  ['public', 'sales', 'rev', '17'],
#  ['public', 'sales', 'lost', '17'],
#  ['public', 'sales', 'closed', '17'],
#  ['cpgsample.public', 'supplier', 's_nationkey', '11'],
#  ['cpgsample.public', 'lineitem', 'l_linenumber', '11'],
#  ['cpgsample.public', 'lineitem', 'l_quantity', '11'],
#  ['cpgsample.public', 'part', 'p_type', '11'],
#  ['cpgsample.public', 'lineitem', 'l_extendedprice', '11'],
#  ['cpgsample.public', 'partsupp', 'ps_comment', '11'],
#  ['cpgsample.public', 'part', 'p_mfgr', '11'],
#  ['cpgsample.public', 'lineitem', 'l_discount', '11'],
#  ['cpgsample.public', 'lineitem', 'l_commitdate', '11'],
#  ['cpgsample.public', 'customer', 'c_address', '11'],
#  ['cpgsample.public', 'orders', 'o_orderpriority', '11'],
#  ['cpgsample.public', 'supplier', 's_comment', '11'],
#  ['cpgsample.public', 'partsupp', 'ps_supplycost', '11'],
#  ['cpgsample.public', 'lineitem', 'l_returnflag', '11'],
#  ['cpgsample.public', 'lineitem', 'l_receiptdate', '11'],
#  ['cpgsample.public', 'supplier', 's_name', '11'],
#  ['cpgsample.public', 'customer', 'c_name', '11'],
#  ['cpgsample.public', 'lineitem', 'l_shipdate', '11'],
#  ['cpgsample.public', 'nation', 'n_name', '11'],
#  ['cpgsample.public', 'lineitem', 'l_shipmode', '11'],
#  ['cpgsample.public', 'orders', 'o_comment', '11'],
#  ['cpgsample.public', 'lineitem', 'l_comment', '11'],
#  ['cpgsample.public', 'supplier', 's_address', '11'],
#  ['cpgsample.public',
#   'v_open_orders_with_discontinued_suppliers',
#   'o_orderdate',
#   '11'],
#  ['cpgsample.public', 'part', 'p_brand', '11'],
#  ['cpgsample.public', 'lineitem', 'l_shipinstruct', '11'],
#  ['cpgsample.public', 'region', 'r_name', '11'],
#  ['cpgsample.public', 'part', 'p_name', '11'],
#  ['cpgsample.public', 'customer', 'c_comment', '11'],
#  ['cpgsample.public', 'part', 'p_comment', '11'],
#  ['cpgsample.public', 'supplier', 's_phone', '11'],
#  ['cpgsample.public', 'part', 'p_retailprice', '11'],
#  ['cpgsample.public', 'nation', 'n_regionkey', '11'],
#  ['cpgsample.public', 'customer', 'c_phone', '11'],
#  ['cpgsample.public', 'customer', 'c_acctbal', '11'],
#  ['cpgsample.public', 'lineitem', 'l_partkey', '11'],
#  ['cpgsample.public', 'part', 'p_size', '11'],
#  ['cpgsample.public',
#   'v_open_orders_with_discontinued_suppliers',
#   'l_suppkey',
#   '11'],
#  ['cpgsample.public', 'region', 'r_regionkey', '11'],
#  ['cpgsample.public', 'orders', 'o_totalprice', '11'],
#  ['cpgsample.public',
#   'v_open_orders_with_discontinued_suppliers',
#   'l_quantity',
#   '11'],
#  ['cpgsample.public', 'lineitem', 'l_tax', '11'],
#  ['cpgsample.public', 'customer', 'c_custkey', '11'],
#  ['cpgsample.public', 'partsupp', 'ps_availqty', '11'],
#  ['cpgsample.public', 'orders', 'o_shippriority', '11'],
#  ['cpgsample.public',
#   'v_open_orders_with_discontinued_suppliers',
#   'o_totalprice',
#   '11'],
#  ['cpgsample.public', 'lineitem', 'l_linestatus', '11'],
#  ['cpgsample.public', 'orders', 'o_custkey', '11'],
#  ['cpgsample.public',
#   'v_open_orders_with_discontinued_suppliers',
#   'l_partkey',
#   '11'],
#  ['cpgsample.public', 'region', 'r_comment', '11'],
#  ['cpgsample.public', 'nation', 'n_nationkey', '11'],
#  ['cpgsample.public', 'orders', 'o_orderkey', '11'],
#  ['cpgsample.public',
#   'v_open_orders_with_discontinued_suppliers',
#   'c_name',
#   '11'],
#  ['cpgsample.public', 'customer', 'c_nationkey', '11'],
#  ['cpgsample.public', 'lineitem', 'l_orderkey', '11'],
#  ['cpgsample.public',
#   'v_open_orders_with_discontinued_suppliers',
#   'o_orderkey',
#   '11'],
#  ['cpgsample.public', 'orders', 'o_orderstatus', '11'],
#  ['cpgsample.public', 'customer', 'c_mktsegment', '11'],
#  ['cpgsample.public', 'partsupp', 'ps_suppkey', '11'],
#  ['cpgsample.public', 'part', 'p_partkey', '11'],
#  ['cpgsample.public', 'orders', 'o_orderdate', '11'],
#  ['cpgsample.public', 'orders', 'o_clerk', '11'],
#  ['cpgsample.public', 'supplier', 's_acctbal', '11'],
#  ['cpgsample.public', 'partsupp', 'ps_partkey', '11'],
#  ['cpgsample.public', 'lineitem', 'l_suppkey', '11'],
#  ['cpgsample.public',
#   'v_open_orders_with_discontinued_suppliers',
#   's_name',
#   '11'],
#  ['cpgsample.public', 'nation', 'n_comment', '11'],
#  ['cpgsample.public', 'part', 'p_container', '11'],
#  ['cpgsample.public', 'supplier', 's_suppkey', '11'],
#  ['bank', 'trade_transactions_rms', 'fundsplitallocationid', '6'],
#  ['bank', 'trade_transactions_rms', 'clearingbrokeryn', '6'],
#  ['bank', 'trade_rms', 'exercisedintosourcesystemid', '6'],
#  ['loan_data', 'full_loan_details', 'verification_status', '6'],
#  ['loan_data', 'full_loan_details', 'title', '6'],
#  ['bank', 'trade_rms', 'modeltype', '6'],
#  ['bank', 'trade_transactions_rms', 'version', '6'],
#  ['bank', 'trade_transactions_rms', 'referenceforwardpoints', '6'],
#  ['bank', 'trade_rms', 'referencedeporate', '6'],
#  ['loan_data', 'full_loan_details', 'settlement_date', '6'],
#  ['bank', 'trade_transactions_rms', 'previoussettlementsystem', '6'],
#  ['bank', 'trade_transactions_rms', 'cancellinghalfsourcesystemid', '6'],
#  ['bank', 'trade_rms', 'bookinglocation', '6'],
#  ['loan_data', 'full_loan_details', 'total_rev_hi_lim', '6'],
#  ['bank', 'trade_rms', 'settlementlegalentitylocation', '6'],
#  ['bank', 'trade_rms', 'dominantnotional', '6'],
#  ['loan_data', 'full_loan_details', 'tot_cur_bal', '6'],
#  ['bank', 'trade_rms', 'electedsettlementsystem', '6'],
#  ['bank', 'trade_rms', 'closessourcesystemid', '6'],
#  ['loan_data', 'full_loan_details', 'sec_app_chargeoff_within_12_mths', '6'],
#  ['bank', 'trade_rms', 'premiumcurrency', '6'],
#  ['loan_data', 'dclnd_loans', 'amount_requested', '6'],
#  ['loan_data', 'full_loan_details', 'initial_list_status', '6'],
#  ['bank', 'trade_transactions_rms', 'dbriskproduct', '6'],
#  ['loan_data', 'full_loan_details', 'mths_since_recent_bc', '6'],
#  ['loan_data', 'full_loan_details', 'loan_id', '6'],
#  ['bank', 'trade_transactions_rms', 'latestexecutingplatform', '6'],
#  ['cust_data', 'accts_by_zip', 'num_retire', '6'],
#  ['cust_data', 'acct_type', 'investing', '6'],
#  ['bank', 'trade_rms', 'zonecut', '6'],
#  ['bank', 'trade_transactions_rms', 'lastexcessreturnindexfixing', '6'],
#  ['bank', 'trade_transactions_rms', 'returnleverage', '6'],
#  ['loan_data', 'full_loan_details', 'acc_now_delinq', '6'],
#  ['loan_data', 'full_loan_details', 'hardship_flag', '6'],
#  ['ins', 'claim_fin_q4_15', 'date_of_birth', '6'],
#  ['loan_data', 'full_loan_details', 'settlement_status', '6'],
#  ['bank', 'trade_transactions_rms', 'dbrpid', '6'],
#  ['bank', 'trade_transactions_rms', 'forwardpricinglocation', '6'],
#  ['loan_data', 'full_loan_details', 'member_id', '6'],
#  ['bank', 'trade_rms', 'originalexecutingplatform', '6'],
#  ['bank', 'trade_transactions_rms', 'nextfixingdate', '6'],
#  ['loan_data',
#   'full_loan_details',
#   'sec_app_mths_since_last_major_derog',
#   '6'],
#  ['bank', 'trade_transactions_rms', 'atrisklocation', '6'],
#  ['bank', 'trade_rms', 'dealcapturesalesuser', '6'],
#  ['cust_data', 'accts_by_zip', 'num_bank', '6'],
#  ['ins', 'claim_fin_q4_15', 'injury_category', '6'],
#  ['loan_data', 'full_loan_details', 'purpose', '6'],
#  ['bank', 'trade_rms', 'enteredby', '6'],
#  ['bank', 'trade_rms', 'previoussettlementsystem', '6'],
#  ['bank', 'trade_rms', 'producttype', '6'],
#  ['loan_data', 'full_loan_details', 'hardship_loan_status', '6'],
#  ['bank', 'trade_rms', 'dealcapturesystem', '6'],
#  ['bank', 'trade_transactions_rms', 'futurecode', '6'],
#  ['bank', 'trade_transactions_rms', 'counterparty', '6'],
#  ['loan_data', 'full_loan_details', 'all_util', '6'],
#  ['bank', 'trade_transactions_rms', 'atriskamt', '6'],
#  ['bank', 'trade_rms', 'originalsettlementdate', '6'],
#  ['loan_data', 'full_loan_details', 'open_act_il', '6'],
#  ['loan_data', 'full_loan_details', 'num_actv_rev_tl', '6'],
#  ['bank', 'trade_transactions_rms', 'premiumdate', '6'],
#  ['bank', 'trade_rms', 'correctedbysourcesystemid', '6'],
#  ['bank', 'trade_transactions_rms', 'backofficesystem', '6'],
#  ['ins', 'claim_fin_q4_15', 'tot_rcvry_amt', '6'],
#  ['bank', 'trade_rms', 'childforwardpips', '6'],
#  ['loan_data', 'full_loan_details', 'policy_code', '6'],
#  ['bank', 'trade_rms', 'unwindpremiumamount', '6'],
#  ['bank', 'trade_rms', 'marginpaymentcurrency', '6'],
#  ['bank', 'trade_rms', 'legalentity', '6'],
#  ['bank', 'trade_rms', 'premiumdate', '6'],
#  ['bank', 'trade_transactions_rms', 'originalsettlementdate', '6'],
#  ['bank', 'trade_transactions_rms', 'exercisedfromsourcesystemid', '6'],
#  ['loan_data', 'dclnd_loans', 'risk_score', '6'],
#  ['loan_data', 'dclnd_loans', 'application_date', '6'],
#  ['bank', 'trade_rms', 'counterpartyname', '6'],
#  ['bank', 'trade_rms', 'premiumhaspaidyn', '6'],
#  ['bank', 'trade_transactions_rms', 'lastfundedindexfixing', '6'],
#  ['loan_data', 'full_loan_details', 'mths_since_recent_bc_dlq', '6'],
#  ['bank', 'trade_transactions_rms', 'originalcptysourcesystem', '6'],
#  ['loan_data', 'full_loan_details', 'term', '6'],
#  ['loan_data', 'full_loan_details', 'total_cu_tl', '6'],
#  ['bank', 'trade_rms', 'accnotional', '6'],
#  ['bank', 'trade_transactions_rms', 'generaterisksweeptradeyn', '6'],
#  ['loan_data', 'dclnd_loans', 'loan_title', '6'],
#  ['loan_data', 'full_loan_details', 'total_bc_limit', '6'],
#  ['bank', 'trade_rms', 'clearingclientsourcesystem', '6'],
#  ['bank', 'trade_transactions_rms', 'fundsplitallocationlegid', '6'],
#  ['bank', 'trade_transactions_rms', 'fundedindexfixingref', '6'],
#  ['bank', 'trade_transactions_rms', 'atriskadditionalamt', '6'],
#  ['bank', 'trade_rms', 'productid', '6'],
#  ['bank', 'trade_rms', 'markupamt', '6'],
#  ['bank', 'trade_rms', 'undercurrency', '6'],
#  ['bank', 'trade_transactions_rms', 'sourcesystemid', '6'],
#  ['bank', 'trade_rms', 'dbriskproduct', '6'],
#  ['bank', 'account_detail', 'custid', '6'],
#  ['bank', 'trade_rms', 'fundedindexfixingref', '6'],
#  ['bank', 'trade_transactions_rms', 'linktype', '6'],
#  ['bank', 'trade_transactions_rms', 'matcherblockid', '6'],
#  ['loan_data', 'full_loan_details', 'pub_rec', '6'],
#  ['bank', 'trade_transactions_rms', 'unwindpremiumamount', '6'],
#  ['bank', 'trade_rms', 'usiproduct', '6'],
#  ['loan_data', 'full_loan_details', 'total_rec_int', '6'],
#  ['bank', 'trade_transactions_rms', 'optionpricinglocation', '6'],
#  ['bank', 'trade_rms', 'risksweeplinkmastersystemid', '6'],
#  ['bank', 'trade_transactions_rms', 'confirmas', '6'],
#  ['bank', 'trade_transactions_rms', 'acccurrency', '6'],
#  ['loan_data', 'full_loan_details', 'mths_since_recent_revol_delinq', '6'],
#  ['loan_data', 'full_loan_details', 'earliest_cr_line', '6'],
#  ['bank', 'trade_rms', 'riskbtbgloballegstatus', '6'],
#  ['bank', 'trade_rms', 'electedconfirmationruleid', '6'],
#  ['loan_data', 'full_loan_details', 'open_rv_24m', '6'],
#  ['loan_data', 'full_loan_details', 'hardship_status', '6'],
#  ['cust_data', 'profile', 'city', '6'],
#  ['loan_data', 'full_loan_details', 'funded_amnt_inv', '6'],
#  ['bank', 'trade_transactions_rms', 'previousconfirmationsystem', '6'],
#  ['bank', 'trade_rms', 'expirydate', '6'],
#  ['bank', 'trade_rms', 'dbicounterpartyid', '6'],
#  ['bank', 'trade_rms', 'clientclearingbroker', '6'],
#  ['bank', 'trade_rms', 'unwindrate', '6'],
#  ['bank', 'trade_rms', 'sourcesystemprofitcentre', '6'],
#  ['bank', 'trade_rms', 'cancellinghalfsourcesystemid', '6'],
#  ['loan_data', 'full_loan_details', 'settlement_term', '6'],
#  ['loan_data', 'full_loan_details', 'tot_hi_cred_lim', '6'],
#  ['bank', 'trade_rms', 'nextfixingdate', '6'],
#  ['bank', 'account_detail', 'city', '6'],
#  ['loan_data', 'full_loan_details', 'num_actv_bc_tl', '6'],
#  ['bank', 'trade_transactions_rms', 'tradetype', '6'],
#  ['ins', 'claim_fin_q4_15', 'alc_rcvry_amt', '6'],
#  ['loan_data', 'full_loan_details', 'open_il_12m', '6'],
#  ['ins', 'claim_fin_q4_15', 'gender', '6'],
#  ['bank', 'trade_transactions_rms', 'usinamespace', '6'],
#  ['bank', 'trade_rms', 'childmarginpips', '6'],
#  ['bank', 'trade_transactions_rms', 'referencespot', '6'],
#  ['bank', 'trade_transactions_rms', 'risksweeplinkmastersystemid', '6'],
#  ['loan_data', 'full_loan_details', 'sec_app_num_rev_accts', '6'],
#  ['loan_data', 'full_loan_details', 'issue_d', '6'],
#  ['loan_data', 'full_loan_details', 'hardship_dpd', '6'],
#  ['loan_data', 'full_loan_details', 'annual_inc_joint', '6'],
#  ['bank', 'trade_transactions_rms', 'counterpartysourcesystem', '6'],
#  ['bank', 'trade_transactions_rms', 'salesperson', '6'],
#  ['bank', 'trade_transactions_rms', 'productid', '6'],
#  ['bank', 'trade_transactions_rms', 'brokerccy', '6'],
#  ['loan_data', 'full_loan_details', 'hardship_type', '6'],
#  ['loan_data', 'full_loan_details', 'pct_tl_nvr_dlq', '6'],
#  ['cust_data', 'accts_by_zip', 'zipcode', '6'],
#  ['loan_data', 'dclnd_loans', 'member_id', '6'],
#  ['bank', 'trade_transactions_rms', 'producttype', '6'],
#  ['bank', 'trade_rms', 'excessreturnindexfixingref', '6'],
#  ['bank', 'trade_transactions_rms', 'locallegalentitysettlementyn', '6'],
#  ['bank', 'trade_rms', 'optionpricinglocation', '6'],
#  ['bank', 'trade_rms', 'dealcapturesystemid', '6'],
#  ['bank', 'trade_transactions_rms', 'fromlinktype', '6'],
#  ['loan_data', 'full_loan_details', 'debt_settlement_flag_date', '6'],
#  ['bank', 'trade_rms', 'futurecode', '6'],
#  ['bank', 'trade_transactions_rms', 'enteredby', '6'],
#  ['bank', 'trade_transactions_rms', 'expirydate', '6'],
#  ['bank', 'trade_transactions_rms', 'assetlocation', '6'],
#  ['bank', 'trade_transactions_rms', 'reason', '6'],
#  ['loan_data', 'full_loan_details', 'settlement_percentage', '6'],
#  ['loan_data', 'full_loan_details', 'total_bal_il', '6'],
#  ['bank', 'trade_rms', 'forwardpricinglocation', '6'],
#  ['bank', 'trade_rms', 'referencedelta', '6'],
#  ['loan_data', 'full_loan_details', 'pub_rec_bankruptcies', '6'],
#  ['bank', 'trade_rms', 'dbppid', '6'],
#  ['bank', 'trade_rms', 'atriskadditionalamt', '6'],
#  ['bank', 'trade_rms', 'strike', '6'],
#  ['bank', 'trade_rms', 'structurename', '6'],
#  ['bank', 'trade_transactions_rms', 'marginpaymentcurrency', '6'],
#  ['ins', 'claim_fin_q4_15', 'alc_paid_amt', '6'],
#  ['loan_data', 'full_loan_details', 'addr_state', '6'],
#  ['bank', 'trade_transactions_rms', 'dealcapturesystem', '6'],
#  ['bank', 'trade_transactions_rms', 'childforwardpips', '6'],
#  ['bank', 'trade_transactions_rms', 'referencedepocurrency', '6'],
#  ['bank', 'trade_rms', 'riskholdinglinkmastersystemid', '6'],
#  ['bank', 'trade_rms', 'brokerccy', '6'],
#  ['bank', 'trade_transactions_rms', 'clearinghousetradeid', '6'],
#  ['bank', 'trade_transactions_rms', 'dbphysicalproduct', '6'],
#  ['bank', 'trade_rms', 'counterpartysourcesystem', '6'],
#  ['loan_data', 'full_loan_details', 'mort_acc', '6'],
#  ['loan_data', 'full_loan_details', 'hardship_last_payment_amount', '6'],
#  ['cust_data', 'profile', 'zipcode', '6'],
#  ['bank', 'trade_transactions_rms', 'broker', '6'],
#  ['bank', 'trade_transactions_rms', 'counterpartyname', '6'],
#  ['cust_data', 'acct_type', 'real_estate', '6'],
#  ['bank', 'trade_rms', 'matcherblockid', '6'],
#  ['loan_data', 'full_loan_details', 'loan_status', '6'],
#  ['bank', 'trade_transactions_rms', 'closedbysourcesystemid', '6'],
#  ['bank', 'trade_rms', 'atrisklocation', '6'],
#  ['bank', 'trade_rms', 'sourcesystem', '6'],
#  ['bank', 'trade_transactions_rms', 'referencedeporate', '6'],
#  ['loan_data', 'full_loan_details', 'max_bal_bc', '6'],
#  ['loan_data', 'full_loan_details', 'home_ownership', '6'],
#  ['bank', 'trade_transactions_rms', 'customersourcesystem', '6'],
#  ['ins', 'lu_cause', 'id', '6'],
#  ['bank', 'trade_rms', 'blotter', '6'],
#  ['loan_data', 'full_loan_details', 'total_pymnt', '6'],
#  ['bank', 'trade_rms', 'clearingstatus', '6'],
#  ['bank', 'trade_rms', 'notes', '6'],
#  ['bank', 'trade_rms', 'book', '6'],
#  ['bank', 'trade_rms', 'trader', '6'],
#  ['loan_data', 'full_loan_details', 'delinq_2yrs', '6'],
#  ['bank', 'trade_rms', 'paycurrency', '6'],
#  ['bank', 'account_detail', 'firstname', '6'],
#  ['bank', 'trade_transactions_rms', 'closingdate', '6'],
#  ['bank', 'trade_rms', 'risksweepundercurrency', '6'],
#  ['loan_data', 'full_loan_details', 'chargeoff_within_12_mths', '6'],
#  ['loan_data', 'full_loan_details', 'revol_bal_joint', '6'],
#  ['bank', 'trade_rms', 'createdby', '6'],
#  ['bank', 'trade_rms', 'latestsource', '6'],
#  ['bank', 'trade_transactions_rms', 'datecreated', '6'],
#  ['bank', 'trade_transactions_rms', 'lastupdated', '6'],
#  ['bank', 'trade_rms', 'risksweepbook', '6'],
#  ['bank', 'trade_rms', 'marginpaymentamount', '6'],
#  ['bank', 'customer', 'city', '6'],
#  ['bank', 'trade_rms', 'sourcesystembook', '6'],
#  ['loan_data', 'full_loan_details', 'mths_since_rcnt_il', '6'],
#  ['ins', 'claim_fin_q4_15', 'ind_incurred_amt', '6'],
#  ['bank', 'trade_transactions_rms', 'risksweepclientstrike', '6'],
#  ['bank', 'trade_rms', 'actioneffectivedate', '6'],
#  ['bank', 'trade_transactions_rms', 'backofficesystemid', '6'],
#  ['loan_data', 'full_loan_details', 'emp_title', '6'],
#  ['bank', 'trade_transactions_rms', 'marketspread', '6'],
#  ['bank', 'trade_rms', 'tradedate', '6'],
#  ['loan_data', 'full_loan_details', 'hardship_reason', '6'],
#  ['bank', 'trade_transactions_rms', 'latestversionyn', '6'],
#  ['bank', 'trade_transactions_rms', 'tradeid', '6'],
#  ['loan_data', 'full_loan_details', 'settlement_amount', '6'],
#  ['bank', 'trade_rms', 'systemid', '6'],
#  ['bank', 'trade_transactions_rms', 'referencevolatility', '6'],
#  ['bank', 'trade_transactions_rms', 'dominantnotional', '6'],
#  ['bank', 'trade_transactions_rms', 'premiumhaspaidyn', '6'],
#  ['bank', 'trade_rms', 'tradeextradetailversion', '6'],
#  ['loan_data', 'full_loan_details', 'grade', '6'],
#  ['bank', 'trade_transactions_rms', 'riskbtbgloballegstatus', '6'],
#  ['cust_data', 'acct_type', 'banking', '6'],
#  ['bank', 'trade_rms', 'usinamespace', '6'],
#  ['bank', 'trade_rms', 'sourcesystemid', '6'],
#  ['bank', 'trade_rms', 'settlementcounterparty', '6'],
#  ['bank', 'trade_transactions_rms', 'clearingclientsourcesystem', '6'],
#  ['bank', 'trade_transactions_rms', 'clearingclient', '6'],
#  ['loan_data', 'full_loan_details', 'open_rv_12m', '6'],
#  ['bank', 'trade_transactions_rms', 'correctedbysourcesystemid', '6'],
#  ['bank', 'trade_rms', 'originalcounterparty', '6'],
#  ['cust_data', 'accts_by_occu', 'num_restat', '6'],
#  ['cust_data', 'accts_by_zip', 'num_inves', '6'],
#  ['ins', 'claim_fin_q4_15', 'ind_rcvry_amt', '6'],
#  ['loan_data', 'full_loan_details', 'num_tl_120dpd_2m', '6'],
#  ['bank', 'account_detail', 'lastname', '6'],
#  ['bank', 'trade_rms', 'closedbysourcesystemid', '6'],
#  ['bank', 'trade_transactions_rms', 'scalingfactor', '6'],
#  ['loan_data', 'full_loan_details', 'sec_app_open_act_il', '6'],
#  ['cust_data', 'profile', 'state', '6'],
#  ['bank', 'trade_transactions_rms', 'referencedeltacurrency', '6'],
#  ['cust_data', 'acct_status', 'uuid', '6'],
#  ['ins', 'claim_fin_q4_15', 'claim_id', '6'],
#  ['bank', 'trade_transactions_rms', 'cancelssourcesystemid', '6'],
#  ['bank', 'trade_rms', 'previousconfirmationsystem', '6'],
#  ['bank', 'trade_rms', 'usileg', '6'],
#  ['loan_data', 'full_loan_details', 'last_pymnt_amnt', '6'],
#  ['bank', 'trade_transactions_rms', 'dealcapturesalesuser', '6'],
#  ['loan_data', 'full_loan_details', 'num_tl_90g_dpd_24m', '6'],
#  ['bank', 'trade_transactions_rms', 'clearingstatus', '6'],
#  ['cust_data', 'profile', 'uuid', '6'],
#  ['loan_data', 'full_loan_details', 'num_rev_tl_bal_gt_0', '6'],
#  ['bank', 'trade_rms', 'risksweeptradetype', '6'],
#  ['bank', 'trade_rms', 'linktype', '6'],
#  ['bank', 'trade_transactions_rms', 'dbicounterpartyid', '6'],
#  ['bank', 'trade_transactions_rms', 'referencedelta', '6'],
#  ['bank', 'trade_transactions_rms', 'unwindrate', '6'],
#  ['bank', 'trade_rms', 'assetlocation', '6'],
#  ['bank', 'trade_transactions_rms', 'undercurrency', '6'],
#  ['bank', 'trade_transactions_rms', 'dbppid', '6'],
#  ['loan_data', 'full_loan_details', 'il_util', '6'],
#  ['loan_data', 'full_loan_details', 'hardship_length', '6'],
#  ['bank', 'trade_rms', 'atriskamt', '6'],
#  ['bank', 'trade_rms', 'cancelledbysourcesystemid', '6'],
#  ['ins', 'claim_fin_q4_15', 'ind_paid_amt', '6'],
#  ['bank', 'trade_transactions_rms', 'clientclearingbroker', '6'],
#  ['bank', 'trade_rms', 'tradeextradetailid', '6'],
#  ['loan_data', 'full_loan_details', 'mo_sin_old_rev_tl_op', '6'],
#  ['bank', 'trade_transactions_rms', 'structurename', '6'],
#  ['bank', 'trade_transactions_rms', 'customer', '6'],
#  ['bank', 'trade_transactions_rms', 'sourcesystem', '6'],
#  ['loan_data', 'full_loan_details', 'delinq_amnt', '6'],
#  ['bank', 'trade_rms', 'structurer', '6'],
#  ['loan_data', 'full_loan_details', 'hardship_start_date', '6'],
#  ['bank', 'trade_transactions_rms', 'cancelledbysourcesystemid', '6'],
#  ['bank', 'trade_transactions_rms', 'electedconfirmationruleid', '6'],
#  ['bank', 'trade_rms', 'referencedeltacurrency', '6'],
#  ['bank', 'trade_transactions_rms', 'bookinglocation', '6'],
#  ['bank', 'trade_rms', 'generaterisksweeptradeyn', '6'],
#  ['bank', 'trade_transactions_rms', 'modeltype', '6'],
#  ['loan_data', 'full_loan_details', 'zip_code', '6'],
#  ['loan_data', 'full_loan_details', 'mo_sin_old_il_acct', '6'],
#  ['bank', 'trade_rms', 'lastfundedindexfixing', '6'],
#  ['bank', 'trade_rms', 'reason', '6'],
#  ['bank', 'trade_rms', 'originalcptysourcesystem', '6'],
#  ['bank', 'trade_rms', 'confirmas', '6'],
#  ['loan_data', 'full_loan_details', 'pymnt_plan', '6'],
#  ['bank', 'trade_transactions_rms', 'electedsettlementsystem', '6'],
#  ['bank', 'trade_transactions_rms', 'premiumamount', '6'],
#  ['loan_data', 'full_loan_details', 'mo_sin_rcnt_tl', '6'],
#  ['bank', 'trade_transactions_rms', 'fixing', '6'],
#  ['bank', 'trade_transactions_rms', 'spotpricinglocation', '6'],
#  ['bank', 'trade_rms', 'riskholdingbook', '6'],
#  ['loan_data', 'full_loan_details', 'next_pymnt_d', '6'],
#  ['bank', 'trade_rms', 'rmssource', '6'],
#  ['loan_data', 'full_loan_details', 'hardship_end_date', '6'],
#  ['bank', 'trade_transactions_rms', 'risksweepacccurrency', '6'],
#  ['bank', 'trade_rms', 'lastexcessreturnindexfixing', '6'],
#  ['loan_data', 'full_loan_details', 'num_accts_ever_120_pd', '6'],
#  ['bank', 'trade_rms', 'clearingeligibleyn', '6'],
#  ['bank', 'trade_transactions_rms', 'tradedate', '6'],
#  ['loan_data', 'full_loan_details', 'acc_open_past_24mths', '6'],
#  ['bank', 'trade_rms', 'settlementdate', '6'],
#  ['bank', 'trade_rms', 'unwindpremiumdate', '6'],
#  ['bank', 'trade_transactions_rms', 'correctssourcesystemid', '6'],
#  ['ins', 'claim_fin_q4_15', 'med_rcvry_amt', '6'],
#  ['bank', 'trade_transactions_rms', 'usileg', '6'],
#  ['cust_data', 'acct_status', 'opened_account', '6'],
#  ['bank', 'customer', 'state', '6'],
#  ['bank', 'trade_rms', 'returnleverage', '6'],
#  ['bank', 'trade_rms', 'atriskccy', '6'],
#  ['bank', 'trade_transactions_rms', 'markupamt', '6'],
#  ['bank', 'trade_rms', 'clearingcancelstatus', '6'],
#  ['loan_data', 'full_loan_details', 'total_bal_ex_mort', '6'],
#  ['bank', 'trade_rms', 'fundsplitallocationlegid', '6'],
#  ['bank', 'trade_rms', 'tradetype', '6'],
#  ['bank', 'trade_transactions_rms', 'accnotional', '6'],
#  ['bank', 'trade_transactions_rms', 'originalexecutingplatform', '6'],
#  ['bank', 'trade_transactions_rms', 'structurer', '6'],
#  ['bank', 'trade_rms', 'tearupid', '6'],
#  ['bank', 'trade_transactions_rms', 'sourcesystemprofitcentre', '6'],
#  ['bank', 'customer', 'custid', '6'],
#  ['bank', 'trade_rms', 'drawdownstartdate', '6'],
#  ['bank', 'trade_transactions_rms', 'tradeextradetailid', '6'],
#  ['loan_data', 'full_loan_details', 'mths_since_last_delinq', '6'],
#  ['bank', 'trade_transactions_rms', 'clearingccp', '6'],
#  ['ins', 'claim_fin_q4_15', 'med_paid_amt', '6'],
#  ['loan_data', 'full_loan_details', 'verification_status_joint', '6'],
#  ['bank', 'trade_rms', 'version', '6'],
#  ['bank', 'trade_rms', 'dbrpid', '6'],
#  ['bank', 'trade_transactions_rms', 'systemid', '6'],
#  ['loan_data', 'full_loan_details', 'descr', '6'],
#  ['loan_data', 'full_loan_details', 'disbursement_method', '6'],
#  ['loan_data', 'full_loan_details', 'mths_since_recent_inq', '6'],
#  ['bank', 'trade_transactions_rms', 'fixingcities', '6'],
#  ['loan_data', 'full_loan_details', 'num_tl_op_past_12m', '6'],
#  ['bank', 'trade_transactions_rms', 'legalentity', '6'],
#  ['bank', 'trade_transactions_rms', 'settlementlegalentitylocation', '6'],
#  ['bank', 'trade_rms', 'referencedepocurrency', '6'],
#  ['bank', 'account_detail', 'flag3', '6'],
#  ['ins', 'claim_fin_q4_15', 'clmt_occu_at_injury', '6'],
#  ['loan_data', 'full_loan_details', 'open_acc_6m', '6'],
#  ['bank', 'trade_transactions_rms', 'zonecut', '6'],
#  ['loan_data', 'full_loan_details', 'revol_bal', '6'],
#  ['cust_data', 'accts_by_occu', 'num_banking', '6'],
#  ['loan_data', 'full_loan_details', 'url', '6'],
#  ['bank', 'trade_transactions_rms', 'originalsource', '6'],
#  ['bank', 'trade_transactions_rms', 'atriskindicator', '6'],
#  ['bank', 'trade_transactions_rms', 'trader', '6'],
#  ['bank', 'trade_rms', 'matchertradeid', '6'],
#  ['loan_data', 'full_loan_details', 'sec_app_revol_util', '6'],
#  ['bank', 'trade_rms', 'cancelssourcesystemid', '6'],
#  ['bank', 'trade_rms', 'productlegid', '6'],
#  ['ins', 'claim_fin_q4_15', 'inj_cause_id', '6'],
#  ['bank', 'trade_transactions_rms', 'quantolevel', '6'],
#  ['bank', 'trade_transactions_rms', 'tearupid', '6'],
#  ['bank', 'trade_rms', 'quantolevel', '6'],
#  ['bank', 'trade_transactions_rms', 'productinstance', '6'],
#  ['loan_data', 'full_loan_details', 'installment', '6'],
#  ['loan_data', 'full_loan_details', 'inq_last_12m', '6'],
#  ['bank', 'trade_rms', 'fixingdate', '6'],
#  ['bank', 'trade_transactions_rms', 'matcher', '6'],
#  ['bank', 'trade_rms', 'action', '6'],
#  ['bank', 'trade_rms', 'fromlinktype', '6'],
#  ['bank', 'customer', 'lastname', '6'],
#  ['bank', 'trade_rms', 'generatebacktobacktradeyn', '6'],
#  ['cust_data', 'occup_lu', 'id', '6'],
#  ['loan_data', 'full_loan_details', 'hardship_payoff_balance_amount', '6'],
#  ['loan_data', 'full_loan_details', 'inq_fi', '6'],
#  ['bank', 'trade_transactions_rms', 'futuresexpirydate', '6'],
#  ['loan_data', 'full_loan_details', 'bc_open_to_buy', '6'],
#  ['loan_data', 'full_loan_details', 'num_il_tl', '6'],
#  ['bank', 'trade_transactions_rms', 'sourcesystembook', '6'],
#  ['bank', 'trade_rms', 'atriskindicator', '6'],
#  ['bank', 'trade_rms', 'fixingreference', '6'],
#  ['ins', 'claim_fin_q4_15', 'injury_type_descr', '6'],
#  ['loan_data', 'full_loan_details', 'avg_cur_bal', '6'],
#  ['loan_data', 'full_loan_details', 'inq_last_6mths', '6'],
#  ['bank', 'trade_transactions_rms', 'unwindpremiumcurrency', '6'],
#  ['bank', 'trade_rms', 'internalgroupid', '6'],
#  ['bank', 'trade_transactions_rms', 'drawdownstartdate', '6'],
#  ['bank', 'trade_rms', 'tradeid', '6'],
#  ['bank', 'trade_rms', 'latestversionyn', '6'],
#  ['bank', 'trade_rms', 'backofficesystem', '6'],
#  ['loan_data', 'full_loan_details', 'num_bc_sats', '6'],
#  ['bank', 'trade_transactions_rms', 'closessourcesystemid', '6'],
#  ['cust_data', 'accts_by_zip', 'last_ran', '6'],
#  ['bank', 'trade_rms', 'tolinktype', '6'],
#  ['bank', 'trade_transactions_rms', 'markupccy', '6'],
#  ['bank', 'trade_transactions_rms', 'rmssource', '6'],
#  ['bank', 'account_detail', 'account_balance', '6'],
#  ['bank', 'trade_transactions_rms', 'tradeclassification', '6'],
#  ['cust_data', 'accts_by_occu', 'num_inves', '6'],
#  ['bank', 'trade_rms', 'correctssourcesystemid', '6'],
#  ['bank', 'trade_rms', 'structureid', '6'],
#  ['loan_data', 'full_loan_details', 'payment_plan_start_date', '6'],
#  ['bank', 'trade_transactions_rms', 'notional', '6'],
#  ['bank', 'trade_transactions_rms', 'marginpaymentamount', '6'],
#  ['bank', 'trade_rms', 'closingdate', '6'],
#  ['bank', 'trade_transactions_rms', 'risksweepsettlementdate', '6'],
#  ['bank', 'trade_transactions_rms', 'linksystemid', '6'],
#  ['loan_data', 'full_loan_details', 'collection_recovery_fee', '6'],
#  ['loan_data', 'full_loan_details', 'sec_app_inq_last_6mths', '6'],
#  ['bank', 'trade_rms', 'electedconfirmationsystem', '6'],
#  ['loan_data', 'full_loan_details', 'total_rec_prncp', '6'],
#  ['cust_data', 'acct_type', 'retirement', '6'],
#  ['bank', 'trade_transactions_rms', 'latestsource', '6'],
#  ['bank', 'trade_transactions_rms', 'risksweepbook', '6'],
#  ['cust_data', 'profile', 'occupation', '6'],
#  ['loan_data', 'full_loan_details', 'percent_bc_gt_75', '6'],
#  ['bank', 'trade_rms', 'clientcbsourcesystem', '6'],
#  ['loan_data', 'full_loan_details', 'open_acc', '6'],
#  ['loan_data', 'full_loan_details', 'annual_inc', '6'],
#  ['bank', 'trade_transactions_rms', 'fixingreference', '6'],
#  ['bank', 'trade_rms', 'brokeramt', '6'],
#  ['bank', 'trade_transactions_rms', 'riskholdingbook', '6'],
#  ['bank', 'trade_transactions_rms', 'createdby', '6'],
#  ['loan_data', 'full_loan_details', 'sec_app_open_acc', '6'],
#  ['bank', 'trade_transactions_rms', 'clearingfundname', '6'],
#  ['loan_data', 'full_loan_details', 'loan_amnt', '6'],
#  ['bank', 'trade_transactions_rms', 'striketermsasentered', '6'],
#  ['loan_data', 'full_loan_details', 'total_il_high_credit_limit', '6'],
#  ['loan_data', 'dclnd_loans', 'policy_code', '6'],
#  ['bank', 'trade_rms', 'tradeclassification', '6'],
#  ['bank', 'trade_rms', 'locallegalentitysettlementyn', '6'],
#  ['bank', 'trade_transactions_rms', 'excessreturnindexfixingref', '6'],
#  ['loan_data', 'dclnd_loans', 'debt_to_income_ratio', '6'],
#  ['bank', 'trade_transactions_rms', 'structureid', '6'],
#  ['bank', 'trade_rms', 'fundsplitallocationid', '6'],
#  ['bank', 'trade_transactions_rms', 'settlementcptysourcesystem', '6'],
#  ['loan_data', 'full_loan_details', 'emp_length', '6'],
#  ['bank', 'trade_rms', 'risksweepclientstrike', '6'],
#  ['loan_data', 'full_loan_details', 'mths_since_last_major_derog', '6'],
#  ['bank', 'trade_rms', 'premiumamount', '6'],
#  ['bank', 'trade_transactions_rms', 'status', '6'],
#  ['bank', 'trade_rms', 'clearinghousetradeid', '6'],
#  ['bank', 'trade_rms', 'lastupdated', '6'],
#  ['loan_data', 'full_loan_details', 'dti', '6'],
#  ['loan_data', 'full_loan_details', 'num_bc_tl', '6'],
#  ['bank', 'trade_rms', 'marketspread', '6'],
#  ['bank', 'trade_transactions_rms', 'paycurrency', '6'],
#  ['bank', 'trade_transactions_rms', 'blotter', '6'],
#  ['bank', 'trade_rms', 'backofficesystemid', '6'],
#  ['bank', 'trade_rms', 'datecreated', '6'],
#  ['bank', 'trade_rms', 'fundsplitversion', '6'],
#  ['bank', 'account_detail', 'flag2', '6'],
#  ['bank', 'trade_transactions_rms', 'unwindpremiumdate', '6'],
#  ['bank', 'trade_transactions_rms', 'markuplocation', '6'],
#  ['bank', 'trade_transactions_rms', 'productversion', '6'],
#  ['bank', 'trade_transactions_rms', 'notes', '6'],
#  ['loan_data', 'full_loan_details', 'tax_liens', '6'],
#  ['bank', 'trade_rms', 'versionvaliduntildate', '6'],
#  ['ins', 'claim_fin_q4_15', 'injury_code', '6'],
#  ['ins', 'claim_fin_q4_15', 'tot_paid_amt', '6'],
#  ['bank', 'trade_transactions_rms', 'strikeasentered', '6'],
#  ['loan_data', 'full_loan_details', 'funded_amnt', '6'],
#  ['loan_data',
#   'full_loan_details',
#   'orig_projected_additional_accrued_interest',
#   '6'],
#  ['bank', 'trade_rms', 'customer', '6'],
#  ['loan_data', 'full_loan_details', 'tot_coll_amt', '6'],
#  ['ins', 'claim_fin_q4_15', 'med_incurred_amt', '6'],
#  ['bank', 'trade_transactions_rms', 'fixingdate', '6'],
#  ['bank', 'trade_transactions_rms', 'clearingeligibleyn', '6'],
#  ['loan_data', 'full_loan_details', 'total_rec_late_fee', '6'],
#  ['loan_data', 'full_loan_details', 'num_op_rev_tl', '6'],
#  ['bank', 'trade_rms', 'productinstance', '6'],
#  ['cust_data', 'acct_status', 'closed_account', '6'],
#  ['bank', 'trade_rms', 'risksweepacccurrency', '6'],
#  ['bank', 'trade_transactions_rms', 'atriskccy', '6'],
#  ['loan_data', 'full_loan_details', 'total_acc', '6'],
#  ['loan_data', 'full_loan_details', 'bc_util', '6'],
#  ['cust_data', 'accts_by_occu', 'num_retire', '6'],
#  ['bank', 'trade_rms', 'status', '6'],
#  ['bank', 'trade_transactions_rms', 'clearingcancelstatus', '6'],
#  ['ins', 'claim_fin_q4_15', 'acc_cause_id', '6'],
#  ['ins', 'claim_fin_q4_15', 'alc_incurred_amt', '6'],
#  ['loan_data', 'full_loan_details', 'last_credit_pull_d', '6'],
#  ['bank', 'trade_rms', 'originalsource', '6'],
#  ['bank', 'trade_transactions_rms', 'dealcapturesystemid', '6'],
#  ['loan_data', 'dclnd_loans', 'employment_length', '6'],
#  ['bank', 'trade_rms', 'broker', '6'],
#  ['bank', 'trade_rms', 'futuresexpirydate', '6'],
#  ['bank', 'trade_rms', 'customersourcesystem', '6'],
#  ['bank', 'trade_rms', 'referenceforwardpoints', '6'],
#  ['loan_data', 'full_loan_details', 'deferral_term', '6'],
#  ['bank', 'trade_transactions_rms', 'clearingfundnamesourcesystem', '6'],
#  ['bank', 'trade_rms', 'salesperson', '6'],
#  ['bank', 'trade_rms', 'latestexecutingplatform', '6'],
#  ['bank', 'trade_rms', 'striketermsasentered', '6'],
#  ['bank', 'trade_rms', 'dbphysicalproduct', '6'],
#  ['bank', 'trade_rms', 'fixingcities', '6'],
#  ['bank', 'trade_transactions_rms', 'riskholdinglinkmastersystemid', '6'],
#  ['bank', 'trade_transactions_rms', 'tradeextradetailversion', '6'],
#  ['bank', 'trade_rms', 'spotpricinglocation', '6'],
#  ['bank', 'trade_rms', 'fixing', '6'],
#  ['bank', 'trade_transactions_rms', 'strike', '6'],
#  ['loan_data', 'full_loan_details', 'num_sats', '6'],
#  ['bank', 'trade_transactions_rms', 'tolinktype', '6'],
#  ['bank', 'trade_rms', 'linksystemid', '6'],
#  ['loan_data', 'full_loan_details', 'out_prncp', '6'],
#  ['bank', 'trade_rms', 'markupccy', '6'],
#  ['bank', 'trade_rms', 'fundsplitid', '6'],
#  ['bank', 'trade_rms', 'referencespot', '6'],
#  ['bank', 'trade_rms', 'productversion', '6'],
#  ['bank', 'trade_rms', 'risksweepsettlementdate', '6'],
#  ['bank', 'trade_rms', 'clearingbrokeryn', '6'],
#  ['bank', 'trade_transactions_rms', 'brokeramt', '6'],
#  ['loan_data', 'full_loan_details', 'num_tl_30dpd', '6'],
#  ['bank', 'trade_transactions_rms', 'action', '6'],
#  ['cust_data', 'acct_type', 'uuid', '6'],
#  ['bank', 'trade_rms', 'unwindpremiumcurrency', '6'],
#  ['bank', 'trade_transactions_rms', 'originalcounterparty', '6'],
#  ['loan_data', 'full_loan_details', 'application_type', '6'],
#  ['bank', 'trade_rms', 'settlementcptysourcesystem', '6'],
#  ['loan_data', 'dclnd_loans', 'dti_decimal', '6'],
#  ['loan_data', 'full_loan_details', 'sub_grade', '6'],
#  ['bank', 'customer', 'acount_number', '6'],
#  ['loan_data', 'full_loan_details', 'open_il_24m', '6'],
#  ['bank', 'trade_transactions_rms', 'clientcbsourcesystem', '6'],
#  ['cust_data', 'occup_lu', 'occupation', '6'],
#  ['bank', 'trade_rms', 'clearingfundname', '6'],
#  ['loan_data', 'full_loan_details', 'sec_app_collections_12_mths_ex_med', '6'],
#  ['bank', 'trade_rms', 'markuplocation', '6'],
#  ['loan_data', 'full_loan_details', 'num_rev_accts', '6'],
#  ['bank', 'trade_transactions_rms', 'electedsettlementruleid', '6'],
#  ['loan_data', 'full_loan_details', 'int_rate', '6'],
#  ['bank', 'trade_transactions_rms', 'generatebacktobacktradeyn', '6'],
#  ['loan_data', 'full_loan_details', 'collections_12_mths_ex_med', '6'],
#  ['bank', 'trade_transactions_rms', 'matchertradeid', '6'],
#  ['loan_data', 'dclnd_loans', 'loan_id', '6'],
#  ['bank', 'trade_rms', 'notional', '6'],
#  ['bank', 'trade_transactions_rms', 'internalgroupid', '6'],
#  ['bank', 'trade_transactions_rms', 'risksweeptradetype', '6'],
#  ['bank', 'account_detail', 'state', '6'],
#  ['bank', 'trade_transactions_rms', 'electedconfirmationsystem', '6'],
#  ['cust_data', 'accts_by_occu', 'id', '6'],
#  ['loan_data', 'full_loan_details', 'sec_app_earliest_cr_line', '6'],
#  ['bank', 'trade_rms', 'clearingclient', '6'],
#  ['bank', 'account_detail', 'cosigner', '6'],
#  ['loan_data', 'full_loan_details', 'sec_app_mort_acc', '6'],
#  ['loan_data', 'full_loan_details', 'total_pymnt_inv', '6'],
#  ['bank', 'trade_rms', 'traderrate', '6'],
#  ['ins', 'claim_fin_q4_15', 'tot_incurred_amt', '6'],
#  ['loan_data', 'full_loan_details', 'hardship_amount', '6'],
#  ['loan_data', 'full_loan_details', 'out_prncp_inv', '6'],
#  ['bank', 'trade_rms', 'strikeasentered', '6'],
#  ['bank', 'customer', 'firstname', '6'],
#  ['loan_data', 'full_loan_details', 'dti_joint', '6'],
#  ['bank', 'trade_transactions_rms', 'productlegid', '6'],
#  ['loan_data', 'full_loan_details', 'revol_util', '6'],
#  ['bank', 'account_detail', 'acount_number', '6'],
#  ['bank', 'trade_rms', 'clearingccp', '6'],
#  ['bank', 'trade_transactions_rms', 'settlementcounterparty', '6'],
#  ['bank', 'trade_transactions_rms', 'exercisedintosourcesystemid', '6'],
#  ['bank', 'trade_rms', 'matcher', '6'],
#  ['bank', 'trade_transactions_rms', 'childmarginpips', '6'],
#  ['loan_data', 'full_loan_details', 'mths_since_last_record', '6'],
#  ['bank', 'trade_transactions_rms', 'fundsplitversion', '6'],
#  ['ins', 'claim_fin_q4_15', 'body_part', '6'],
#  ['loan_data', 'full_loan_details', 'debt_settlement_flag', '6'],
#  ['bank', 'trade_transactions_rms', 'usiproduct', '6'],
#  ['loan_data', 'full_loan_details', 'mo_sin_rcnt_rev_tl_op', '6'],
#  ['bank', 'trade_rms', 'risksweepstrike', '6'],
#  ['cust_data', 'accts_by_zip', 'num_restat', '6'],
#  ['bank', 'trade_transactions_rms', 'risksweepundercurrency', '6'],
#  ['bank', 'trade_transactions_rms', 'risksweepstrike', '6'],
#  ['bank', 'trade_transactions_rms', 'versionvaliduntildate', '6'],
#  ['ins', 'lu_cause', 'cause_desc', '6'],
#  ['bank', 'trade_rms', 'referencevolatility', '6'],
#  ['loan_data', 'full_loan_details', 'last_pymnt_d', '6'],
#  ['loan_data', 'full_loan_details', 'recoveries', '6'],
#  ['bank', 'trade_rms', 'acccurrency', '6'],
#  ['bank', 'trade_transactions_rms', 'traderrate', '6'],
#  ['bank', 'trade_transactions_rms', 'fundsplitid', '6'],
#  ['bank', 'trade_rms', 'counterparty', '6'],
#  ['bank', 'trade_rms', 'exercisedfromsourcesystemid', '6'],
#  ['bank', 'trade_transactions_rms', 'actioneffectivedate', '6'],
#  ['bank', 'trade_transactions_rms', 'settlementdate', '6'],
#  ['bank', 'trade_rms', 'electedsettlementruleid', '6'],
#  ['ins', 'claim_fin_q4_15', 'acc_site_desc', '6'],
#  ['bank', 'trade_transactions_rms', 'premiumcurrency', '6'],
#  ['bank', 'trade_transactions_rms', 'book', '6'],
#  ['bank', 'trade_rms', 'scalingfactor', '6'],
#  ['bank', 'trade_rms', 'clearingfundnamesourcesystem', '6'],
#  ['loan_data', 'declnd_loans_stats', 'avg_risk', '5'],
#  ['loan_data', 'full_loan_details_full', 'pct_tl_nvr_dlq', '5'],
#  ['loan_data',
#   'full_loan_details_full',
#   'sec_app_collections_12_mths_ex_med',
#   '5'],
#  ['loan_data', 'full_loan_details_full', 'inq_last_12m', '5'],
#  ['loan_data', 'full_loan_details_full', 'total_pymnt', '5'],
#  ['loan_data', 'full_loan_details_full', 'hardship_last_payment_amount', '5'],
#  ['bank', 'uic_credit_data_2', 'pay_0', '5'],
#  ['loan_data', 'full_loan_details_full', 'sec_app_open_act_il', '5'],
#  ['loan_data', 'full_loan_details_full', 'mths_since_rcnt_il', '5'],
#  ['loan_data', 'full_loan_details_full', 'open_il_24m', '5'],
#  ['bank', 'uci_credit_card', 'pay_3', '5'],
#  ['bank', 'dictionary_reporting', 'type_of_data', '5'],
#  ['bank', 'uic_credit_data_2', 'pay_amt3', '5'],
#  ['loan_data', 'full_loan_details_full', 'application_type', '5'],
#  ['bank', 'uic_credit_data_2', 'age', '5'],
#  ['bank', 'dictionary_reporting', 'business_criticality', '5'],
#  ['bank', 'uic_credit_card_4', 'bill_amt1', '5'],
#  ['bank', 'dictionary_reporting', 'retention_period', '5'],
#  ['bank', 'mrkt_seg', 'conversion_flag', '5'],
#  ['bank', 'uic_credit_data_2', 'bill_amt3', '5'],
#  ['loan_data', 'full_loan_details_full', 'emp_length', '5'],
#  ['bank', 'uic_credit_card_4', 'pay_amt4', '5'],
#  ['loan_data', 'full_loan_details_full', 'sec_app_mort_acc', '5'],
#  ['loan_data', 'full_loan_details_full', 'sec_app_earliest_cr_line', '5'],
#  ['loan_data', 'full_loan_details_full', 'out_prncp_inv', '5'],
#  ['loan_data', 'full_loan_details_full', 'hardship_amount', '5'],
#  ['loan_data', 'full_loan_details_full', 'collections_12_mths_ex_med', '5'],
#  ['bank', 'mrkt_seg', 'market_segment_id', '5'],
#  ['bank', 'uic_credit_data_2', 'pay_6', '5'],
#  ['bank', 'dictionary_reporting', 'steward_groupprofile', '5'],
#  ['bank', 'trade_type_summary', 'num', '5'],
#  ['cust_data', 'loan_rates', 'funded_amnt', '5'],
#  ['loan_data', 'declnd_loans_stats', 'occupation', '5'],
#  ['bank', 'mrkt_seg', 'plan_name1', '5'],
#  ['loan_data', 'full_loan_details_full', 'debt_settlement_flag', '5'],
#  ['loan_data', 'full_loan_details_full', 'sub_grade', '5'],
#  ['loan_data', 'full_loan_details_full', 'tot_cur_bal', '5'],
#  ['bank', 'uic_credit_data_3', 'pay_amt4', '5'],
#  ['loan_data', 'full_loan_details_full', 'bc_util', '5'],
#  ['bank', 'uic_credit_data_2', 'pay_amt2', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_op_rev_tl', '5'],
#  ['bank', 'dictionary_reporting', 'technical_owner_user', '5'],
#  ['bank', 'mrkt_seg', 'plan_num', '5'],
#  ['bank', 'uic_credit_data_2', 'default_payment_next_month', '5'],
#  ['bank', 'uci_credit_card', 'bill_amt6', '5'],
#  ['loan_data', 'full_loan_details_full', 'collection_recovery_fee', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_sats', '5'],
#  ['bank', 'dictionary_reporting', 'contains_pii', '5'],
#  ['bank', 'dictionary_reporting', 'main_dataset_region', '5'],
#  ['bank', 'uic_credit_data_2', 'marriage', '5'],
#  ['bank', 'uic_credit_data_2', 'sex', '5'],
#  ['loan_data', 'full_loan_details_full', 'total_rec_late_fee', '5'],
#  ['bank', 'trade_type_summary', 'tradedate_yr', '5'],
#  ['bank', 'uic_credit_data_2', 'pay_2', '5'],
#  ['bank', 'uci_credit_card', 'education', '5'],
#  ['loan_data', 'full_loan_details_full', 'total_acc', '5'],
#  ['bank', 'uic_credit_data_3', 'pay_4', '5'],
#  ['loan_data', 'dclnd_loan_occ', 'amount_requested', '5'],
#  ['bank', 'uci_credit_card', 'pay_5', '5'],
#  ['bank', 'uci_credit_card', 'pay_2', '5'],
#  ['bank', 'uci_credit_card', 'default_payment_next_month', '5'],
#  ['bank', 'uci_credit_card', 'bill_amt5', '5'],
#  ['loan_data', 'full_loan_details', 'city', '5'],
#  ['loan_data', 'full_loan_details_full', 'settlement_status', '5'],
#  ['loan_data', 'full_loan_details_full', 'hardship_flag', '5'],
#  ['loan_data', 'full_loan_details_full', 'funded_amnt_inv', '5'],
#  ['loan_data', 'full_loan_details', 'uuid', '5'],
#  ['bank', 'uic_credit_data_3', 'id', '5'],
#  ['bank', 'uic_credit_card_4', 'bill_amt4', '5'],
#  ['loan_data', 'full_loan_details_full', 'open_act_il', '5'],
#  ['bank', 'uci_credit_card', 'bill_amt2', '5'],
#  ['loan_data', 'full_loan_details_full', 'tot_hi_cred_lim', '5'],
#  ['bank', 'uic_credit_data_3', 'pay_amt1', '5'],
#  ['loan_data', 'full_loan_details_full', 'verification_status_joint', '5'],
#  ['bank', 'uci_credit_card', 'marriage', '5'],
#  ['loan_data', 'full_loan_details_full', 'hardship_length', '5'],
#  ['bank', 'mrkt_seg', 'share_class', '5'],
#  ['bank', 'uci_credit_card', 'sex', '5'],
#  ['loan_data', 'full_loan_details_full', 'mths_since_recent_bc', '5'],
#  ['bank', 'mrkt_seg', 'original_eff_date', '5'],
#  ['loan_data', 'full_loan_details_full', 'total_rev_hi_lim', '5'],
#  ['loan_data', 'full_loan_details_full', 'loan_id', '5'],
#  ['bank', 'uci_credit_card', 'pay_amt2', '5'],
#  ['bank', 'uic_credit_card_4', 'pay_amt5', '5'],
#  ['bank', 'uci_credit_card', 'pay_6', '5'],
#  ['bank', 'dictionary_reporting', 'title', '5'],
#  ['loan_data', 'full_loan_details_full', 'term', '5'],
#  ['cust_data', 'loan_rates', 'int_rate', '5'],
#  ['loan_data', 'full_loan_details_full', 'mo_sin_rcnt_rev_tl_op', '5'],
#  ['bank', 'uic_credit_data_3', 'bill_amt2', '5'],
#  ['bank', 'uic_credit_card_4', 'bill_amt5', '5'],
#  ['bank', 'uic_credit_data_3', 'pay_amt5', '5'],
#  ['loan_data', 'full_loan_details_full', 'total_bc_limit', '5'],
#  ['bank', 'dictionary_reporting', 'data_profile', '5'],
#  ['loan_data', 'full_loan_details_full', 'last_pymnt_d', '5'],
#  ['loan_data', 'full_loan_details_full', 'policy_code', '5'],
#  ['loan_data', 'full_loan_details_full', 'deferral_term', '5'],
#  ['bank', 'uic_credit_card_4', 'pay_5', '5'],
#  ['ins_new', 'all_claims_new', 'age', '5'],
#  ['loan_data', 'full_loan_details_full', 'mo_sin_old_rev_tl_op', '5'],
#  ['bank', 'uci_credit_card', 'pay_amt3', '5'],
#  ['loan_data', 'full_loan_details_full', 'recoveries', '5'],
#  ['loan_data', 'full_loan_details_full', 'total_cu_tl', '5'],
#  ['loan_data', 'full_loan_details_full', 'mo_sin_old_il_acct', '5'],
#  ['bank', 'uci_credit_card', 'pay_0', '5'],
#  ['loan_data', 'full_loan_details_full', 'pub_rec_bankruptcies', '5'],
#  ['loan_data', 'full_loan_details_full', 'open_rv_12m', '5'],
#  ['loan_data', 'full_loan_details_full', 'verification_status', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_tl_120dpd_2m', '5'],
#  ['loan_data', 'full_loan_details_full', 'last_pymnt_amnt', '5'],
#  ['bank', 'uic_credit_card_4', 'bill_amt2', '5'],
#  ['bank', 'uci_credit_card', 'bill_amt3', '5'],
#  ['bank', 'dictionary_reporting', 'risk_sensitivity', '5'],
#  ['loan_data', 'full_loan_details_full', 'grade', '5'],
#  ['bank', 'uic_credit_data_3', 'bill_amt4', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_bc_sats', '5'],
#  ['bank', 'uci_credit_card', 'age', '5'],
#  ['loan_data', 'full_loan_details_full', 'mths_since_last_record', '5'],
#  ['cust_data', 'loan_rates', 'loan_amnt', '5'],
#  ['loan_data', 'full_loan_details_full', 'settlement_amount', '5'],
#  ['bank', 'uic_credit_card_4', 'id', '5'],
#  ['bank', 'mrkt_seg', 'key_account_flag', '5'],
#  ['loan_data', 'full_loan_details_full', 'il_util', '5'],
#  ['loan_data', 'full_loan_details_full', 'open_rv_24m', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_bc_tl', '5'],
#  ['bank', 'uic_credit_data_2', 'pay_3', '5'],
#  ['bank', 'uic_credit_card_4', 'sex', '5'],
#  ['bank', 'uic_credit_data_3', 'pay_5', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_rev_tl_bal_gt_0', '5'],
#  ['bank', 'uic_credit_data_3', 'bill_amt3', '5'],
#  ['bank', 'uic_credit_card_4', 'pay_6', '5'],
#  ['loan_data', 'full_loan_details_full', 'issue_d', '5'],
#  ['bank', 'dictionary_reporting', 'cde_indicator', '5'],
#  ['cust_data', 'loan_rates', 'loan_id', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_tl_90g_dpd_24m', '5'],
#  ['ins_new', 'all_claims_new', 'acc_site_desc', '5'],
#  ['bank', 'uic_credit_data_3', 'pay_0', '5'],
#  ['loan_data', 'full_loan_details_full', 'total_bal_il', '5'],
#  ['bank', 'uic_credit_card_4', 'marriage', '5'],
#  ['loan_data', 'full_loan_details_full', 'hardship_loan_status', '5'],
#  ['loan_data', 'full_loan_details_full', 'debt_settlement_flag_date', '5'],
#  ['loan_data', 'declnd_loans_stats', 'count(occ.occupation)', '5'],
#  ['bank', 'mrkt_seg', 'transition_status', '5'],
#  ['bank', 'uic_credit_data_3', 'default_payment_next_month', '5'],
#  ['loan_data', 'full_loan_details_full', 'earliest_cr_line', '5'],
#  ['loan_data', 'full_loan_details_full', 'revol_bal', '5'],
#  ['bank', 'mrkt_seg', 'turn_off_billing', '5'],
#  ['bank', 'dictionary_reporting', 'archiving_date', '5'],
#  ['loan_data', 'full_loan_details_full', 'settlement_percentage', '5'],
#  ['bank', 'mrkt_seg', 'plan_status', '5'],
#  ['bank', 'uic_credit_card_4', 'default_payment_next_month', '5'],
#  ['bank', 'uic_credit_data_3', 'age', '5'],
#  ['bank', 'uci_credit_card', 'bill_amt4', '5'],
#  ['bank', 'uic_credit_card_4', 'education', '5'],
#  ['bank', 'uic_credit_data_3', 'pay_amt3', '5'],
#  ['loan_data', 'full_loan_details_full', 'mths_since_last_delinq', '5'],
#  ['loan_data', 'full_loan_details_full', 'acc_now_delinq', '5'],
#  ['loan_data', 'full_loan_details_full', 'hardship_status', '5'],
#  ['bank', 'dictionary_reporting', 'pii_compliance', '5'],
#  ['loan_data', 'full_loan_details_full', 'total_bal_ex_mort', '5'],
#  ['loan_data', 'full_loan_details_full', 'member_id', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_accts_ever_120_pd', '5'],
#  ['loan_data', 'full_loan_details_full', 'mo_sin_rcnt_tl', '5'],
#  ['bank', 'uic_credit_data_3', 'pay_2', '5'],
#  ['bank', 'uic_credit_data_2', 'pay_4', '5'],
#  ['bank', 'uic_credit_data_3', 'sex', '5'],
#  ['bank', 'uic_credit_card_4', 'pay_amt2', '5'],
#  ['loan_data', 'full_loan_details', 'occupation', '5'],
#  ['bank', 'uic_credit_card_4', 'pay_0', '5'],
#  ['bank', 'mrkt_seg', 'port_ind', '5'],
#  ['bank', 'uic_credit_card_4', 'pay_2', '5'],
#  ['bank', 'mrkt_seg', 'plan_name2', '5'],
#  ['bank', 'uci_credit_card', 'pay_amt1', '5'],
#  ['loan_data', 'full_loan_details_full', 'loan_amnt', '5'],
#  ['bank', 'uic_credit_data_3', 'bill_amt5', '5'],
#  ['loan_data', 'full_loan_details', 'state', '5'],
#  ['bank', 'dictionary_reporting', 'relevant_dataset_table', '5'],
#  ['bank', 'dictionary_reporting', 'subject_area', '5'],
#  ['bank', 'uic_credit_data_2', 'bill_amt6', '5'],
#  ['bank', 'uic_credit_data_3', 'pay_6', '5'],
#  ['loan_data', 'full_loan_details_full', 'mths_since_recent_bc_dlq', '5'],
#  ['bank', 'uic_credit_data_3', 'pay_amt2', '5'],
#  ['bank', 'uic_credit_card_4', 'bill_amt3', '5'],
#  ['loan_data', 'full_loan_details_full', 'total_rec_int', '5'],
#  ['loan_data', 'full_loan_details_full', 'zip_code', '5'],
#  ['bank', 'uic_credit_card_4', 'pay_amt3', '5'],
#  ['bank', 'uic_credit_data_2', 'pay_amt6', '5'],
#  ['loan_data',
#   'full_loan_details_full',
#   'mths_since_recent_revol_delinq',
#   '5'],
#  ['loan_data', 'full_loan_details_full', 'pub_rec', '5'],
#  ['bank', 'uic_credit_data_2', 'pay_amt4', '5'],
#  ['bank', 'mrkt_seg', 'vrs_flag', '5'],
#  ['loan_data', 'declnd_loans_stats', 'avg_amnt_reqst', '5'],
#  ['bank', 'mrkt_seg', 'unnamed_18', '5'],
#  ['loan_data', 'full_loan_details_full', 'total_pymnt_inv', '5'],
#  ['bank', 'dictionary_reporting', 'description', '5'],
#  ['loan_data', 'full_loan_details_full', 'inq_last_6mths', '5'],
#  ['loan_data', 'full_loan_details_full', 'purpose', '5'],
#  ['bank', 'uci_credit_card', 'pay_amt5', '5'],
#  ['loan_data', 'full_loan_details_full', 'int_rate', '5'],
#  ['bank', 'uci_credit_card', 'pay_amt4', '5'],
#  ['loan_data', 'full_loan_details_full', 'out_prncp', '5'],
#  ['bank', 'uic_credit_card_4', 'pay_amt6', '5'],
#  ['bank', 'uic_credit_data_2', 'pay_amt5', '5'],
#  ['loan_data', 'full_loan_details_full', 'sec_app_open_acc', '5'],
#  ['bank', 'uic_credit_data_2', 'pay_5', '5'],
#  ['loan_data', 'full_loan_details_full', 'funded_amnt', '5'],
#  ['bank', 'dictionary_reporting', 'status_of_development', '5'],
#  ['loan_data', 'full_loan_details_full', 'open_acc', '5'],
#  ['loan_data', 'full_loan_details_full', 'inq_fi', '5'],
#  ['loan_data',
#   'full_loan_details_full',
#   'hardship_payoff_balance_amount',
#   '5'],
#  ['loan_data', 'full_loan_details_full', 'annual_inc_joint', '5'],
#  ['loan_data', 'full_loan_details_full', 'sec_app_num_rev_accts', '5'],
#  ['loan_data', 'full_loan_details_full', 'dti', '5'],
#  ['loan_data', 'full_loan_details_full', 'bc_open_to_buy', '5'],
#  ['loan_data', 'full_loan_details_full', 'hardship_dpd', '5'],
#  ['loan_data',
#   'full_loan_details_full',
#   'sec_app_mths_since_last_major_derog',
#   '5'],
#  ['bank', 'uic_credit_data_3', 'marriage', '5'],
#  ['loan_data', 'dclnd_loan_occ', 'loan_id', '5'],
#  ['bank', 'uic_credit_data_2', 'id', '5'],
#  ['bank', 'uci_credit_card', 'bill_amt1', '5'],
#  ['loan_data', 'full_loan_details_full', 'tax_liens', '5'],
#  ['bank', 'dictionary_reporting', 'reseacher', '5'],
#  ['bank', 'mrkt_seg', 'sponsor_internet_access_flag', '5'],
#  ['bank', 'uci_credit_card', 'pay_4', '5'],
#  ['loan_data',
#   'full_loan_details_full',
#   'sec_app_chargeoff_within_12_mths',
#   '5'],
#  ['loan_data', 'full_loan_details_full', 'tot_coll_amt', '5'],
#  ['bank', 'uic_credit_card_4', 'pay_3', '5'],
#  ['loan_data', 'full_loan_details_full', 'hardship_type', '5'],
#  ['loan_data', 'full_loan_details_full', 'sec_app_inq_last_6mths', '5'],
#  ['loan_data', 'full_loan_details_full', 'all_util', '5'],
#  ['loan_data', 'full_loan_details_full', 'percent_bc_gt_75', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_actv_rev_tl', '5'],
#  ['loan_data', 'full_loan_details_full', 'initial_list_status', '5'],
#  ['loan_data', 'full_loan_details_full', 'next_pymnt_d', '5'],
#  ['loan_data', 'full_loan_details_full', 'max_bal_bc', '5'],
#  ['bank', 'uic_credit_data_2', 'pay_amt1', '5'],
#  ['bank', 'uic_credit_card_4', 'limit_bal', '5'],
#  ['loan_data',
#   'full_loan_details_full',
#   'orig_projected_additional_accrued_interest',
#   '5'],
#  ['loan_data', 'full_loan_details_full', 'annual_inc', '5'],
#  ['loan_data', 'full_loan_details_full', 'avg_cur_bal', '5'],
#  ['loan_data', 'full_loan_details_full', 'disbursement_method', '5'],
#  ['loan_data', 'full_loan_details_full', 'delinq_amnt', '5'],
#  ['loan_data', 'full_loan_details_full', 'loan_status', '5'],
#  ['loan_data', 'full_loan_details_full', 'open_acc_6m', '5'],
#  ['bank', 'dictionary_reporting', 'subject_to_article', '5'],
#  ['loan_data', 'dclnd_loan_occ', 'employment_length', '5'],
#  ['loan_data', 'full_loan_details_full', 'mort_acc', '5'],
#  ['loan_data', 'full_loan_details_full', 'hardship_start_date', '5'],
#  ['loan_data', 'full_loan_details_full', 'descr', '5'],
#  ['bank', 'uic_credit_data_3', 'limit_bal', '5'],
#  ['loan_data', 'full_loan_details_full', 'hardship_reason', '5'],
#  ['loan_data', 'full_loan_details_full', 'installment', '5'],
#  ['bank', 'dictionary_reporting', 'gdpr_data_set_compliance', '5'],
#  ['bank', 'trade_type_summary', 'tradedate_mth', '5'],
#  ['loan_data', 'full_loan_details_full', 'title', '5'],
#  ['bank', 'uic_credit_data_2', 'bill_amt1', '5'],
#  ['loan_data', 'full_loan_details_full', 'total_rec_prncp', '5'],
#  ['bank', 'dictionary_reporting', 'verification_status', '5'],
#  ['loan_data', 'full_loan_details_full', 'open_il_12m', '5'],
#  ['bank', 'uic_credit_data_2', 'bill_amt5', '5'],
#  ['bank', 'uic_credit_data_2', 'limit_bal', '5'],
#  ['bank', 'uci_credit_card', 'id', '5'],
#  ['bank', 'uic_credit_data_3', 'pay_3', '5'],
#  ['bank', 'uic_credit_data_3', 'bill_amt6', '5'],
#  ['bank', 'mrkt_seg', 'deferral_date', '5'],
#  ['loan_data', 'full_loan_details_full', 'delinq_2yrs', '5'],
#  ['loan_data', 'full_loan_details_full', 'settlement_date', '5'],
#  ['loan_data', 'full_loan_details_full', 'chargeoff_within_12_mths', '5'],
#  ['bank', 'uci_credit_card', 'limit_bal', '5'],
#  ['bank', 'trade_type_summary', 'tradetype', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_tl_op_past_12m', '5'],
#  ['bank', 'uic_credit_card_4', 'pay_amt1', '5'],
#  ['bank', 'uic_credit_card_4', 'age', '5'],
#  ['loan_data', 'full_loan_details_full', 'hardship_end_date', '5'],
#  ['loan_data', 'full_loan_details_full', 'acc_open_past_24mths', '5'],
#  ['bank', 'uic_credit_card_4', 'pay_4', '5'],
#  ['loan_data', 'full_loan_details_full', 'last_credit_pull_d', '5'],
#  ['loan_data', 'full_loan_details_full', 'revol_bal_joint', '5'],
#  ['bank', 'uic_credit_data_3', 'education', '5'],
#  ['loan_data', 'full_loan_details_full', 'url', '5'],
#  ['loan_data', 'dclnd_loan_occ', 'occupation', '5'],
#  ['loan_data', 'full_loan_details_full', 'addr_state', '5'],
#  ['loan_data', 'full_loan_details_full', 'revol_util', '5'],
#  ['ins_new', 'all_claims_new', 'injury_type_descr', '5'],
#  ['bank', 'dictionary_reporting', 'steward_user', '5'],
#  ['loan_data', 'full_loan_details_full', 'emp_title', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_actv_bc_tl', '5'],
#  ['bank', 'dictionary_reporting', 'technical_owner_groupprofile', '5'],
#  ['bank', 'dictionary_reporting', 'key', '5'],
#  ['loan_data', 'full_loan_details_full', 'home_ownership', '5'],
#  ['bank', 'uci_credit_card', 'pay_amt6', '5'],
#  ['loan_data', 'full_loan_details_full', 'dti_joint', '5'],
#  ['loan_data', 'full_loan_details_full', 'sec_app_revol_util', '5'],
#  ['loan_data', 'full_loan_details_full', 'total_il_high_credit_limit', '5'],
#  ['loan_data', 'full_loan_details_full', 'pymnt_plan', '5'],
#  ['loan_data', 'full_loan_details_full', 'payment_plan_start_date', '5'],
#  ['loan_data', 'full_loan_details_full', 'mths_since_recent_inq', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_rev_accts', '5'],
#  ['loan_data', 'full_loan_details_full', 'settlement_term', '5'],
#  ['loan_data', 'full_loan_details_full', 'num_tl_30dpd', '5'],
#  ['bank', 'uic_credit_data_2', 'bill_amt4', '5'],
#  ['bank', 'uic_credit_data_2', 'education', '5'],
#  ['bank', 'uic_credit_data_2', 'bill_amt2', '5']]

# %% [markdown]
# The email which we normally get contains a link to download the file. It is created like this...

# %%
print(f'{base_url}/ajax/get_result_table_data/{result_id}/?csv=1')
# Out:
# http://18.218.6.215/ajax/get_result_table_data/148/?csv=1

# %% [markdown]
# # More fun with the unofficial API
#
# Let's see what the unofficial API reveals about our Query...

# %%
otype='query'
id=93
t = alation.generic_api_get(f'/api/{otype}/{id}/')

pp.pprint(t)
# Out:
# {   'author': {   'display_name': 'Helge Schneider',
#                   'email': 'matthias+1@alation.com',
#                   'icon': 'user',
#                   'id': 8,
#                   'is_active': True,
#                   'otype': 'userprofile',
#                   'photo_url': '/static/img/user.png',
#                   'url': '/user/8/'},
#     'autosave_content': None,
#     'can_schedule': True,
#     'collaborators': [],
#     'content': 'select schema_name, table_name, attribute_name, count(1) as '
#                'freq\n'
#                'from public.zucchini\n'
#                'group by 1, 2, 3\n'
#                'order by 4 DESC\n'
#                'limit 1000;\n'
#                '\n'
#                'select now();',
#     'content_for': 'select schema_name, table_name, attribute_name, count(1) '
#                    'as freq\n'
#                    'from public.zucchini\n'
#                    'group by 1, 2, 3\n'
#                    'order by 4 DESC\n'
#                    'limit 1000;\n'
#                    '\n'
#                    'select now();',
#     'cursor_col': 0,
#     'cursor_row': 0,
#     'deleted': False,
#     'description': '<p>i have decided to publish this to enlighten the '
#                    'world</p>\n',
#     'dict_url': '/dict/42/',
#     'discarded': True,
#     'display_content': 'select schema_name, table_name, attribute_name, '
#                        'count(1) as freq\n'
#                        'from public.zucchini\n'
#                        'group by 1, 2, 3\n'
#                        'order by 4 DESC\n'
#                        'limit 1000;\n'
#                        '\n'
#                        'select now();',
#     'ds': {   'dbtype': 'postgresql',
#               'enabled_in_compose': True,
#               'icon': 'db',
#               'id': 42,
#               'otype': 'data',
#               'title': 'Fennel',
#               'url': '/data/42/'},
#     'execution_tally': 0,
#     'favorited_by_list': None,
#     'form_url': '/query/93/form/',
#     'history_url': '/query/93/history/',
#     'icon': 'query',
#     'id': 93,
#     'is_title_editable': True,
#     'last_autosaved_at': None,
#     'last_edited_at': '2020-04-21T07:38:54.181990-07:00',
#     'last_executed_at': None,
#     'last_published_at': '2020-04-21T07:39:17.888823-07:00',
#     'last_saved_at': '2020-04-21T07:39:17.883430-07:00',
#     'last_visited': '2020-04-21T14:38:54.597127Z',
#     'lock': {   'content': 'select schema_name, table_name, attribute_name, '
#                            'count(1) as freq\n'
#                            'from public.zucchini\n'
#                            'group by 1, 2, 3\n'
#                            'order by 4 DESC\n'
#                            'limit 1000;\n'
#                            '\n'
#                            'select now();',
#                 'has_collaborators': False,
#                 'holder': {   'display_name': 'Helge Schneider',
#                               'icon': 'user',
#                               'id': 8,
#                               'is_active': True,
#                               'otype': 'userprofile',
#                               'photo_url': '/static/img/user.png',
#                               'url': '/user/8/'},
#                 'is_expired': False,
#                 'is_released': False,
#                 'last_editor': {   'display_name': 'Helge Schneider',
#                                    'icon': 'user',
#                                    'id': 8,
#                                    'is_active': True,
#                                    'otype': 'userprofile',
#                                    'url': '/user/8/'},
#                 'query_id': 93,
#                 'seconds_to_expiry': 580,
#                 'ts_expired': '2020-04-21T07:50:05.296979-07:00',
#                 'ts_granted': '2020-04-21T07:39:17.852099-07:00',
#                 'ts_last_edited': '2020-04-21T07:39:17.883430-07:00',
#                 'ts_released': None},
#     'num_clones': 0,
#     'num_favs': 0,
#     'otype': 'query',
#     'permissions': [   'VIEW',
#                        'EDIT',
#                        'DELETE',
#                        'CHANGE_OWNER',
#                        'VIEW',
#                        'DELETE',
#                        'CHANGE_OWNER',
#                        'CHANGE_COLLABORATOR',
#                        'CHANGE_COLLABORATOR'],
#     'public_content': 'select schema_name, table_name, attribute_name, '
#                       'count(1) as freq\n'
#                       'from public.zucchini\n'
#                       'group by 1, 2, 3\n'
#                       'order by 4 DESC\n'
#                       'limit 1000;\n'
#                       '\n'
#                       'select now();',
#     'published': True,
#     'published_content': 'select schema_name, table_name, attribute_name, '
#                          'count(1) as freq\n'
#                          'from public.zucchini\n'
#                          'group by 1, 2, 3\n'
#                          'order by 4 DESC\n'
#                          'limit 1000;\n'
#                          '\n'
#                          'select now();',
#     'query_group_ids': [],
#     'saved': True,
#     'schedules': [],
#     'shared_result_users': [],
#     'snippet_name': None,
#     'tags': [],
#     'title': 'base fennel query (Clone)',
#     'ts_created': '2020-04-21T07:38:54.181767-07:00',
#     'ts_deleted': None,
#     'ts_updated': '2020-04-21T07:40:05.315804-07:00',
#     'url': '/query/93/'}

# %%
p = alation.generic_api_patch(f'/api/{otype}/{id}/', body=dict(discarded=True))
p_parsed = json.loads(p)
p_parsed['discarded']
# Out:
# True

# %% [markdown]
# ## Get a file handle to this Notebook
#
# This code won't work for you unless you have access to the file.

# %%
from google.colab import auth
auth.authenticate_user()
from googleapiclient.discovery import build
drive_service = build('drive', 'v3')

response = drive_service.files().list(q="name='Alation API Training Spring 2020.ipynb'",
                                      spaces='drive',
                                      fields='nextPageToken, files(id, name)').execute()
file = response.get('files', [])[0]
print ('Found file: {} {}' .format (file.get('name'), file.get('id')))
alation_notebook = file.get('id')
file
# Out:
# Found file: Alation API Training Spring 2020.ipynb 16BiqA8Oy53iwQumPhIOOI3hfh-GFjntd
# {'id': '16BiqA8Oy53iwQumPhIOOI3hfh-GFjntd',
#  'name': 'Alation API Training Spring 2020.ipynb'}

# %% [markdown]
# Copy the notebook (running this cell only defines the method)

# %%
def copy_notebook(name):
  body = dict(name=name)
  response = drive_service.files().copy(fileId=alation_notebook, body=body).execute()
  return '<p><a href="https://colab.research.google.com/drive/{0}" rel="noopener noreferrer" target="_blank">https://colab.research.google.com/drive/{0}</a></p>'.format(response['id'])

# %%
copy_notebook("My friend.ipynb")
# Out:
# '<p><a href="https://colab.research.google.com/drive/1EhpkAbCK10rYaVBIXi39B7uKVgRODtIG" rel="noopener noreferrer" target="_blank">https://colab.research.google.com/drive/1EhpkAbCK10rYaVBIXi39B7uKVgRODtIG</a></p>'
